# %% [markdown]
# #**Sentiment analysis**

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import ast
import nltk

# Télécharger les ressources nécessaires pour l'analyse de sentiment de NLTK
nltk.download('vader_lexicon')

# Charger les données depuis le fichier CSV (en utilisant un chemin d'accès relatif)
file_path = '/content/youtube_data_vf.csv'
df = pd.read_csv(file_path)

# Remplacer les valeurs NaN par des listes vides
df['comments'] = df['comments'].fillna('[]')

# Afficher les commentaires avant d'appliquer le modèle d'analyse de sentiment
print("Comments before sentiment analysis:")
print(df['comments'])

# Créer une instance de l'analyseur de sentiment
sid = SentimentIntensityAnalyzer()

# Fonction pour obtenir le sentiment pour chaque commentaire
def get_sentiment(comment):
    sentiment_score = sid.polarity_scores(comment)
    if sentiment_score['compound'] >= 0.05:
        return 'Positive'
    elif sentiment_score['compound'] <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Convertir les chaînes de caractères en listes de commentaires
df['comments'] = df['comments'].apply(ast.literal_eval)

# Appliquer l'analyse de sentiment sur chaque commentaire individuellement
df['sentiment'] = df['comments'].apply(lambda x: get_sentiment(x[0] if len(x) > 0 else ''))

# Afficher les résultats
print("\nSentiment analysis results:")
print(df[['comments', 'sentiment']])
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Comments before sentiment analysis:
# 0      ['Thanks for all the support over the years ga...
# 1      ['20-30 minutes a day 4 days a week. I believe...
# 2      ['❤❤❤', 'انا لست ربوت حتى استمر فقط في العمل و...
# 3      ['As an author myself, I\'ve found it difficul...
# 4      ['What was the most useful/interesting part of...
#                              ...
# 908    ['The nostalgia', 'love it. the high pitched n...
# 909    ['Love ❤ Ali Abdaal', "watching Ali's videos a...
# 910    ['Wow ali ❤️', 'Ali 3rd viedeo', 'Where is ali...
# 911    ["Assalamualaikum sir with due respect I wants...
# 912    ['The beginnings of a productive legend ❤ even...
# Name: comments, Length: 913, dtype: object
#
# Sentiment analysis results:
#                                               comments sentiment
# 0    [Thanks for all the support over the years gan...  Positive
# 1    [20-30 minutes a day 4 days a week. I believe ...  Positive
# 2    [❤❤❤, انا لست ربوت حتى استمر فقط في العمل وامض...   Neutral
# 3    [As an author myself, I've found it difficult ...  Negative
# 4    [What was the most useful/interesting part of ...   Neutral
# ..                                                 ...       ...
# 908  [The nostalgia, love it. the high pitched note...   Neutral
# 909  [Love ❤ Ali Abdaal, watching Ali's videos abou...  Positive
# 910  [Wow ali ❤️, Ali 3rd viedeo, Where is ali?, wa...  Positive
# 911  [Assalamualaikum sir with due respect I wants ...  Positive
# 912  [The beginnings of a productive legend ❤ even ...  Positive
#
# [913 rows x 2 columns]

# %% [markdown]
# # **Comments Translation**

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.5.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.4 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.5 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.1 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.9 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=2770621344090344d948c6091752fec58666117e43d08fc94a16c95f42abf8d8
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.5.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
from transformers import MarianMTModel, MarianTokenizer

# Charger le modèle et le tokenizer pour la traduction de l'anglais vers le français
model_name = "Helsinki-NLP/opus-mt-fr-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Fonction pour traduire chaque commentaire en anglais
def translate_to_english(comments):
    translated_comments = []
    for comment in comments:
        inputs = tokenizer(comment, return_tensors="pt", padding=True, truncation=True)
        translated = model.generate(**inputs)
        translated_text = tokenizer.decode(translated[0], skip_special_tokens=True)
        translated_comments.append(translated_text)
    return translated_comments

# Charger les données et afficher les commentaires avant la traduction
print("Comments before translation:")
print(df['comments'])

# Appliquer la traduction sur chaque commentaire individuellement
df['translated_comments'] = df['comments'].apply(lambda x: translate_to_english(x) if isinstance(x, list) else [])

# Afficher les commentaires après la traduction
print("\nComments after translation:")
print(df['translated_comments'])

# %% [markdown]
# # **Summarize Videos**

# %%
# !pip install -q transformers

# %%
# !pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube_transcript_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube_transcript_api) (2024.2.2)

# %%
# importing libraries
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
btc_video = "https://www.youtube.com/watch?v=5Rqiba5mqLk"

# %%
vid_id = btc_video.split("=")[1]

# %%
vid_id
# Out:
# '5Rqiba5mqLk'

# %%
YouTubeTranscriptApi.get_transcript(vid_id)
# Out:
# [{'text': 'being able to not get distracted is',
#   'start': 0.04,
#   'duration': 5.239},
#  {'text': 'genuinely one of the most life-changing',
#   'start': 2.639,
#   'duration': 4.321},
#  {'text': 'skills if we want to improve our lives',
#   'start': 5.279,
#   'duration': 3.201},
#  {'text': 'in any way if we want to make progress',
#   'start': 6.96,
#   'duration': 3.16},
#  {'text': 'on our studies or in our work or in our',
#   'start': 8.48,
#   'duration': 3.52},
#  {'text': 'side hustle or even like being present',
#   'start': 10.12,
#   'duration': 4.24},
#  {'text': 'with our families for goodness sake that',
#   'start': 12.0,
#   'duration': 4.199},
#  {'text': 'all requires this magical ability called',
#   'start': 14.36,
#   'duration': 3.64},
#  {'text': 'focus it requires the ability to focus',
#   'start': 16.199,
#   'duration': 4.0},
#  {'text': 'on one thing and one thing only and to',
#   'start': 18.0,
#   'duration': 3.96},
#  {'text': 'be fully present in just doing that one',
#   'start': 20.199,
#   'duration': 3.92},
#  {'text': 'bloody thing the thing is we are',
#   'start': 21.96,
#   'duration': 4.319},
#  {'text': 'bombarded by distractions all the time',
#   'start': 24.119,
#   'duration': 3.801},
#  {'text': 'we have our social media notifications',
#   'start': 26.279,
#   'duration': 2.881},
#  {'text': 'pinging right left and Center we have',
#   'start': 27.92,
#   'duration': 2.679},
#  {'text': 'messages and emails and whatsapps and',
#   'start': 29.16,
#   'duration': 3.599},
#  {'text': "text messages and it's like it's so easy",
#   'start': 30.599,
#   'duration': 4.761},
#  {'text': 'to get distracted these days with all of',
#   'start': 32.759,
#   'duration': 3.521},
#  {'text': 'the Endless Options that we have', 'start': 35.36, 'duration': 2.8},
#  {'text': 'available to us and the reason why I',
#   'start': 36.28,
#   'duration': 3.64},
#  {'text': "think it's so incredibly important to",
#   'start': 38.16,
#   'duration': 3.52},
#  {'text': 'cultivate the ability to focus and this',
#   'start': 39.92,
#   'duration': 2.799},
#  {'text': "is the thing that I've really realized",
#   'start': 41.68,
#   'duration': 2.76},
#  {'text': 'over the years that the quality of my',
#   'start': 42.719,
#   'duration': 3.441},
#  {'text': 'life is directly proportional to my',
#   'start': 44.44,
#   'duration': 3.92},
#  {'text': "ability to focus and I've had periods of",
#   'start': 46.16,
#   'duration': 3.52},
#  {'text': "my life where I've really really really",
#   'start': 48.36,
#   'duration': 2.839},
#  {'text': 'struggled to focus my first year of med',
#   'start': 49.68,
#   'duration': 2.679},
#  {'text': 'school for example was a year where I',
#   'start': 51.199,
#   'duration': 2.761},
#  {'text': 'really struggled to focus I was burning',
#   'start': 52.359,
#   'duration': 2.961},
#  {'text': 'the midnight oil feeling really', 'start': 53.96, 'duration': 2.36},
#  {'text': 'overwhelmed feeling really really',
#   'start': 55.32,
#   'duration': 2.36},
#  {'text': "stressed and didn't even do that well in",
#   'start': 56.32,
#   'duration': 3.68},
#  {'text': 'my exams but then as I started to',
#   'start': 57.68,
#   'duration': 3.719},
#  {'text': 'research more about productivity you',
#   'start': 60.0,
#   'duration': 2.719},
#  {'text': 'know reading papers about it doing an',
#   'start': 61.399,
#   'duration': 2.8},
#  {'text': 'extra degree in Psychology as well I I',
#   'start': 62.719,
#   'duration': 3.001},
#  {'text': 'sort of realized that there there',
#   'start': 64.199,
#   'duration': 2.561},
#  {'text': 'actually are a bunch of different',
#   'start': 65.72,
#   'duration': 2.8},
#  {'text': 'techniques that we can learn to help us',
#   'start': 66.76,
#   'duration': 3.44},
#  {'text': 'focus better and if we can just learn',
#   'start': 68.52,
#   'duration': 3.599},
#  {'text': 'and apply those techniques it massively',
#   'start': 70.2,
#   'duration': 4.12},
#  {'text': 'boosts the quality of our life okay so',
#   'start': 72.119,
#   'duration': 3.601},
#  {'text': "in this video we're going to go over the",
#   'start': 74.32,
#   'duration': 4.4},
#  {'text': 'five key mistakes that cause us to get',
#   'start': 75.72,
#   'duration': 5.24},
#  {'text': 'distracted and to not be able to focus',
#   'start': 78.72,
#   'duration': 4.48},
#  {'text': "and let's start with mistake number one",
#   'start': 80.96,
#   'duration': 3.839},
#  {'text': 'now there was one thing that I read that',
#   'start': 83.2,
#   'duration': 3.72},
#  {'text': 'really made this mistake hit home for me',
#   'start': 84.799,
#   'duration': 4.201},
#  {'text': "and that was when I read near eel's book",
#   'start': 86.92,
#   'duration': 3.519},
#  {'text': 'indestructible', 'start': 89.0, 'duration': 2.6},
#  {'text': 'this is a book about how to be',
#   'start': 90.439,
#   'duration': 2.441},
#  {'text': 'indestructible and how to avoid', 'start': 91.6, 'duration': 2.479},
#  {'text': 'distractions and all that kind of fun',
#   'start': 92.88,
#   'duration': 2.16},
#  {'text': "stuff and we're probably going to do a",
#   'start': 94.079,
#   'duration': 2.68},
#  {'text': 'video about it at some point but right',
#   'start': 95.04,
#   'duration': 2.96},
#  {'text': 'at the start of the book he says',
#   'start': 96.759,
#   'duration': 3.761},
#  {'text': 'something like really really profound',
#   'start': 98.0,
#   'duration': 5.119},
#  {'text': 'which is that the opposite of', 'start': 100.52, 'duration': 5.84},
#  {'text': 'distraction is traction and traction is',
#   'start': 103.119,
#   'duration': 4.561},
#  {'text': 'when you are doing something', 'start': 106.36, 'duration': 3.32},
#  {'text': 'intentionally to move you towards where',
#   'start': 107.68,
#   'duration': 4.079},
#  {'text': 'you want to go and distraction is when',
#   'start': 109.68,
#   'duration': 3.88},
#  {'text': 'you are doing something that takes you',
#   'start': 111.759,
#   'duration': 4.04},
#  {'text': 'away from where you want to go but then',
#   'start': 113.56,
#   'duration': 4.08},
#  {'text': 'the next thing he says is that in order',
#   'start': 115.799,
#   'duration': 4.881},
#  {'text': 'to actually know what the thing is you',
#   'start': 117.64,
#   'duration': 4.28},
#  {'text': 'want to do and what the thing is you',
#   'start': 120.68,
#   'duration': 3.28},
#  {'text': 'want to avoid you have to actually have',
#   'start': 121.92,
#   'duration': 4.519},
#  {'text': "a plan cuz if you don't have a plan you",
#   'start': 123.96,
#   'duration': 3.92},
#  {'text': "can't be distracted because you never",
#   'start': 126.439,
#   'duration': 3.361},
#  {'text': 'had a plan to begin with distraction',
#   'start': 127.88,
#   'duration': 3.719},
#  {'text': 'happens when we are intending to do one',
#   'start': 129.8,
#   'duration': 3.88},
#  {'text': 'thing and then we find ourselves doing',
#   'start': 131.599,
#   'duration': 4.761},
#  {'text': 'something else and so mistake number one',
#   'start': 133.68,
#   'duration': 4.04},
#  {'text': 'that we all make that I make all the',
#   'start': 136.36,
#   'duration': 2.44},
#  {'text': 'time when I find myself getting',
#   'start': 137.72,
#   'duration': 4.44},
#  {'text': 'distracted is just not having a plan',
#   'start': 138.8,
#   'duration': 4.84},
#  {'text': "when you don't have a plan and you sit",
#   'start': 142.16,
#   'duration': 3.56},
#  {'text': 'down at your computer or on your phone',
#   'start': 143.64,
#   'duration': 4.84},
#  {'text': 'with nothing in mind as to what you',
#   'start': 145.72,
#   'duration': 4.96},
#  {'text': "actually want to do that is when you're",
#   'start': 148.48,
#   'duration': 3.6},
#  {'text': 'going to end up doing all the other',
#   'start': 150.68,
#   'duration': 4.199},
#  {'text': 'small things this is kind of what social',
#   'start': 152.08,
#   'duration': 4.6},
#  {'text': 'media platforms are designed for when',
#   'start': 154.879,
#   'duration': 3.841},
#  {'text': 'you go on a social media platform you',
#   'start': 156.68,
#   'duration': 4.6},
#  {'text': "don't usually go on it with a particular",
#   'start': 158.72,
#   'duration': 4.159},
#  {'text': "goal in mind it's like someone who's",
#   'start': 161.28,
#   'duration': 3.16},
#  {'text': "just browsing I'm just going to go on",
#   'start': 162.879,
#   'duration': 3.201},
#  {'text': "YouTube and I'm going to see what's up",
#   'start': 164.44,
#   'duration': 3.159},
#  {'text': "I'm literally Outsourcing the decision",
#   'start': 166.08,
#   'duration': 2.879},
#  {'text': "of how I'm going to spend my time which",
#   'start': 167.599,
#   'duration': 2.72},
#  {'text': 'is the single most valuable resource',
#   'start': 168.959,
#   'duration': 2.881},
#  {'text': "that I have I'm Outsourcing that",
#   'start': 170.319,
#   'duration': 3.481},
#  {'text': 'decision to a team of thousands of',
#   'start': 171.84,
#   'duration': 4.72},
#  {'text': 'developers whose in whose goal is to',
#   'start': 173.8,
#   'duration': 4.079},
#  {'text': 'keep me on the platform for as long as',
#   'start': 176.56,
#   'duration': 2.959},
#  {'text': 'possible and to serve me ads for as long',
#   'start': 177.879,
#   'duration': 2.881},
#  {'text': 'as possible so that the platform can',
#   'start': 179.519,
#   'duration': 2.44},
#  {'text': 'make money I like the team behind',
#   'start': 180.76,
#   'duration': 2.479},
#  {'text': "YouTube I've met some of them they're",
#   'start': 181.959,
#   'duration': 3.0},
#  {'text': 'very nice people but like those are the',
#   'start': 183.239,
#   'duration': 2.801},
#  {'text': 'incentives of these social media',
#   'start': 184.959,
#   'duration': 3.161},
#  {'text': 'platforms so the key thing is that we',
#   'start': 186.04,
#   'duration': 4.52},
#  {'text': 'need to make a plan in order to avoid',
#   'start': 188.12,
#   'duration': 3.88},
#  {'text': 'getting distracted and the single',
#   'start': 190.56,
#   'duration': 2.84},
#  {'text': 'biggest mistake that people make that',
#   'start': 192.0,
#   'duration': 2.879},
#  {'text': 'causes them to get distracted is not',
#   'start': 193.4,
#   'duration': 3.24},
#  {'text': 'having a plan this is something n talks',
#   'start': 194.879,
#   'duration': 3.161},
#  {'text': 'about in his book as well he says you',
#   'start': 196.64,
#   'duration': 2.599},
#  {'text': 'know whenever people come to me and they',
#   'start': 198.04,
#   'duration': 2.64},
#  {'text': "say I'm struggling with distraction I",
#   'start': 199.239,
#   'duration': 3.201},
#  {'text': 'struggle to get distracted he says show',
#   'start': 200.68,
#   'duration': 3.68},
#  {'text': 'me your calendar and show me what you',
#   'start': 202.44,
#   'duration': 3.24},
#  {'text': 'were what you were intending to do in',
#   'start': 204.36,
#   'duration': 2.879},
#  {'text': "that time block a if you don't use a",
#   'start': 205.68,
#   'duration': 2.559},
#  {'text': 'calendar you should start using a',
#   'start': 207.239,
#   'duration': 2.08},
#  {'text': "calendar because it's gamechanging",
#   'start': 208.239,
#   'duration': 2.601},
#  {'text': "because it's Lally a log of what you",
#   'start': 209.319,
#   'duration': 3.881},
#  {'text': 'intend to do and B if you have created a',
#   'start': 210.84,
#   'duration': 4.479},
#  {'text': "Time block let's say the in in this",
#   'start': 213.2,
#   'duration': 3.64},
#  {'text': "hourong time block I'm intending to",
#   'start': 215.319,
#   'duration': 3.0},
#  {'text': "write my PowerPoint presentation or I'm",
#   'start': 216.84,
#   'duration': 2.92},
#  {'text': "intending to work on my book or I'm",
#   'start': 218.319,
#   'duration': 2.321},
#  {'text': "intending to film a video or I'm",
#   'start': 219.76,
#   'duration': 2.16},
#  {'text': 'intending to study for the exam whatever',
#   'start': 220.64,
#   'duration': 2.92},
#  {'text': 'the thing is once it is in there as an',
#   'start': 221.92,
#   'duration': 4.2},
#  {'text': 'intention now you can actually have',
#   'start': 223.56,
#   'duration': 4.44},
#  {'text': 'traction and move towards it and the',
#   'start': 226.12,
#   'duration': 3.319},
#  {'text': 'remarkable thing about the human brain',
#   'start': 228.0,
#   'duration': 2.799},
#  {'text': 'is that when we set an intention when we',
#   'start': 229.439,
#   'duration': 3.36},
#  {'text': 'set a goal for something way more likely',
#   'start': 230.799,
#   'duration': 3.561},
#  {'text': 'to Marshall up all the rare all the all',
#   'start': 232.799,
#   'duration': 3.681},
#  {'text': 'the relevant resources and kind of',
#   'start': 234.36,
#   'duration': 4.2},
#  {'text': 'mental faculties to get there whereas if',
#   'start': 236.48,
#   'duration': 3.679},
#  {'text': "we don't set a goal we just going to be",
#   'start': 238.56,
#   'duration': 3.64},
#  {'text': 'ending up kind of a drift now once',
#   'start': 240.159,
#   'duration': 3.64},
#  {'text': "you've mastered the ability to focus and",
#   'start': 242.2,
#   'duration': 3.2},
#  {'text': 'not get distracted then one of the',
#   'start': 243.799,
#   'duration': 2.401},
#  {'text': "things you're going to have to figure",
#   'start': 245.4,
#   'duration': 2.44},
#  {'text': 'out is what you actually want to do with',
#   'start': 246.2,
#   'duration': 3.0},
#  {'text': "all of that spare time that you've got",
#   'start': 247.84,
#   'duration': 3.039},
#  {'text': 'freed up and I know a lot of people in',
#   'start': 249.2,
#   'duration': 3.44},
#  {'text': 'my audience are aspiring content',
#   'start': 250.879,
#   'duration': 3.841},
#  {'text': 'creators or current content creators now',
#   'start': 252.64,
#   'duration': 3.52},
#  {'text': 'if you are in the content creation World',
#   'start': 254.72,
#   'duration': 3.68},
#  {'text': 'in any capacity then one thing that can',
#   'start': 256.16,
#   'duration': 4.12},
#  {'text': 'really help you with ideas or titles or',
#   'start': 258.4,
#   'duration': 3.88},
#  {'text': 'thumbnails or video scripts is', 'start': 260.28, 'duration': 3.84},
#  {'text': 'generative AI which is becoming more and',
#   'start': 262.28,
#   'duration': 3.04},
#  {'text': 'more important and if you want to learn',
#   'start': 264.12,
#   'duration': 3.0},
#  {'text': 'more about using AI for your YouTube',
#   'start': 265.32,
#   'duration': 2.84},
#  {'text': 'channel or your content creative',
#   'start': 267.12,
#   'duration': 2.24},
#  {'text': 'business then I would really recommend',
#   'start': 268.16,
#   'duration': 3.12},
#  {'text': 'you check out the completely free ebook',
#   'start': 269.36,
#   'duration': 3.2},
#  {'text': "that's written by hopspot which is",
#   'start': 271.28,
#   'duration': 3.88},
#  {'text': 'called using generative AI to scale your',
#   'start': 272.56,
#   'duration': 4.079},
#  {'text': 'content operations there is a link in',
#   'start': 275.16,
#   'duration': 2.84},
#  {'text': 'the video description you can downloaded',
#   'start': 276.639,
#   'duration': 2.84},
#  {'text': "completely for free and it's an amazing",
#   'start': 278.0,
#   'duration': 2.72},
#  {'text': 'guide that will get you started with',
#   'start': 279.479,
#   'duration': 3.081},
#  {'text': 'using AI in terms of the different AI',
#   'start': 280.72,
#   'duration': 3.4},
#  {'text': 'tools and how to write prompts for them',
#   'start': 282.56,
#   'duration': 3.24},
#  {'text': 'and all the different ways to use AI for',
#   'start': 284.12,
#   'duration': 3.12},
#  {'text': "your content business you'll understand",
#   'start': 285.8,
#   'duration': 2.72},
#  {'text': 'how to simplify your research how to',
#   'start': 287.24,
#   'duration': 2.84},
#  {'text': 'repurpose content and how to break',
#   'start': 288.52,
#   'duration': 3.16},
#  {'text': 'through writer block as well and me and',
#   'start': 290.08,
#   'duration': 3.2},
#  {'text': 'my team have really found the example',
#   'start': 291.68,
#   'duration': 3.2},
#  {'text': 'prompts and tips in particular for',
#   'start': 293.28,
#   'duration': 3.12},
#  {'text': 'working with AI particularly useful',
#   'start': 294.88,
#   'duration': 2.599},
#  {'text': 'because we are still trying to figure',
#   'start': 296.4,
#   'duration': 3.72},
#  {'text': 'out how to leverage AI for our content',
#   'start': 297.479,
#   'duration': 4.321},
#  {'text': 'but in a way that still retains my voice',
#   'start': 300.12,
#   'duration': 3.32},
#  {'text': 'and like Good Vibes and authenticity and',
#   'start': 301.8,
#   'duration': 3.44},
#  {'text': 'all that kind of fun stuff but does in',
#   'start': 303.44,
#   'duration': 3.52},
#  {'text': 'fact use this amazingly powerful tool',
#   'start': 305.24,
#   'duration': 3.16},
#  {'text': 'that we now have access to this ebook',
#   'start': 306.96,
#   'duration': 2.76},
#  {'text': "was made by HubSpot which is today's",
#   'start': 308.4,
#   'duration': 2.639},
#  {'text': 'video sponsor so thank you very much to',
#   'start': 309.72,
#   'duration': 2.479},
#  {'text': 'HubSpot for sponsoring the video and',
#   'start': 311.039,
#   'duration': 2.44},
#  {'text': 'make sure you check out the completely',
#   'start': 312.199,
#   'duration': 3.081},
#  {'text': "free resource okay let's move on to",
#   'start': 313.479,
#   'duration': 3.401},
#  {'text': "mistake number two now once you've made",
#   'start': 315.28,
#   'duration': 3.12},
#  {'text': "a plan and you're sitting down to do the",
#   'start': 316.88,
#   'duration': 3.4},
#  {'text': 'thing whatever the thing is and you',
#   'start': 318.4,
#   'duration': 3.799},
#  {'text': 'still are finding yourself getting',
#   'start': 320.28,
#   'duration': 5.8},
#  {'text': 'distracted by whatever then the mistake',
#   'start': 322.199,
#   'duration': 6.161},
#  {'text': "people make is thinking I'm just a",
#   'start': 326.08,
#   'duration': 4.2},
#  {'text': "distracted person or I just can't focus",
#   'start': 328.36,
#   'duration': 3.52},
#  {'text': 'or you know you start telling yourself',
#   'start': 330.28,
#   'duration': 3.28},
#  {'text': "these identity type statements that's",
#   'start': 331.88,
#   'duration': 3.28},
#  {'text': 'like a key mistake uh another mistake is',
#   'start': 333.56,
#   'duration': 3.079},
#  {'text': 'to blame the social media companies sure',
#   'start': 335.16,
#   'duration': 2.56},
#  {'text': 'we can blame the social media companies',
#   'start': 336.639,
#   'duration': 2.521},
#  {'text': 'will we like but like you know', 'start': 337.72, 'duration': 2.56},
#  {'text': "fundamentally it's our job to control",
#   'start': 339.16,
#   'duration': 2.479},
#  {'text': 'our and psychology and all that all that',
#   'start': 340.28,
#   'duration': 4.479},
#  {'text': 'fun stuff but really generally when we',
#   'start': 341.639,
#   'duration': 4.4},
#  {'text': "once we've got a plan and we get",
#   'start': 344.759,
#   'duration': 4.241},
#  {'text': "distracted it's because we are it's it's",
#   'start': 346.039,
#   'duration': 4.361},
#  {'text': "because there's some sort of negative",
#   'start': 349.0,
#   'duration': 4.0},
#  {'text': "emotion that's at the root of our",
#   'start': 350.4,
#   'duration': 4.799},
#  {'text': 'distraction and so really mistake number',
#   'start': 353.0,
#   'duration': 5.199},
#  {'text': 'two is ignoring how you feel this is a',
#   'start': 355.199,
#   'duration': 4.481},
#  {'text': 'lot easier for guys to do because',
#   'start': 358.199,
#   'duration': 3.601},
#  {'text': 'normally dudes are really bad me',
#   'start': 359.68,
#   'duration': 4.16},
#  {'text': 'included at understanding how they feel',
#   'start': 361.8,
#   'duration': 4.16},
#  {'text': 'about stuff you might not even be aware',
#   'start': 363.84,
#   'duration': 3.359},
#  {'text': 'that there is some sort of negative',
#   'start': 365.96,
#   'duration': 3.44},
#  {'text': "feeling that you're trying to avoid but",
#   'start': 367.199,
#   'duration': 3.881},
#  {'text': 'here is a rule that I like to I like to',
#   'start': 369.4,
#   'duration': 3.6},
#  {'text': "think of in my life whenever I'm getting",
#   'start': 371.08,
#   'duration': 4.04},
#  {'text': "distracted provided I've got a plan I",
#   'start': 373.0,
#   'duration': 3.88},
#  {'text': 'will just assume that there is some sort',
#   'start': 375.12,
#   'duration': 3.28},
#  {'text': "of emotion that I'm trying to avoid",
#   'start': 376.88,
#   'duration': 3.24},
#  {'text': "that's all there is to it step one do I",
#   'start': 378.4,
#   'duration': 3.48},
#  {'text': 'have a plan and step two okay I have a',
#   'start': 380.12,
#   'duration': 2.84},
#  {'text': "plan and I'm getting distracted",
#   'start': 381.88,
#   'duration': 2.68},
#  {'text': 'therefore what is the negative emotion',
#   'start': 382.96,
#   'duration': 3.0},
#  {'text': "I'm trying to avoid now there are",
#   'start': 384.56,
#   'duration': 3.16},
#  {'text': 'broadly three categories of negative',
#   'start': 385.96,
#   'duration': 4.04},
#  {'text': 'emotion that we try and avoid boredom',
#   'start': 387.72,
#   'duration': 5.039},
#  {'text': 'anxiety and self-doubt again not sexy',
#   'start': 390.0,
#   'duration': 4.28},
#  {'text': "stuff to say if you're a dude watching",
#   'start': 392.759,
#   'duration': 3.401},
#  {'text': 'this but like I I feel anxious and I',
#   'start': 394.28,
#   'duration': 3.56},
#  {'text': 'feel self-doubt and I feel low', 'start': 396.16, 'duration': 3.12},
#  {'text': 'confidence about my ability to do this',
#   'start': 397.84,
#   'duration': 3.639},
#  {'text': "task it's not a thing that we find it",
#   'start': 399.28,
#   'duration': 3.84},
#  {'text': "very easy to admit to ourselves but it's",
#   'start': 401.479,
#   'duration': 3.16},
#  {'text': "true let's start with the anxiety and",
#   'start': 403.12,
#   'duration': 2.88},
#  {'text': 'the self-doubt because like generally',
#   'start': 404.639,
#   'duration': 3.0},
#  {'text': 'the feeling the negative emotion behind',
#   'start': 406.0,
#   'duration': 4.12},
#  {'text': "these two things is fear I am afraid I'm",
#   'start': 407.639,
#   'duration': 4.441},
#  {'text': "not good enough I'm afraid to do this",
#   'start': 410.12,
#   'duration': 3.479},
#  {'text': 'thing I got this a lot when I was',
#   'start': 412.08,
#   'duration': 3.32},
#  {'text': 'writing my book I really struggled cuz I',
#   'start': 413.599,
#   'duration': 4.241},
#  {'text': 'had my time block I had my plan to write',
#   'start': 415.4,
#   'duration': 3.479},
#  {'text': 'however many hundred words or however',
#   'start': 417.84,
#   'duration': 3.0},
#  {'text': 'many thousand words during the session',
#   'start': 418.879,
#   'duration': 3.281},
#  {'text': 'but I had so much anxiety and so much',
#   'start': 420.84,
#   'duration': 3.799},
#  {'text': 'self-doubt around my ability to write a',
#   'start': 422.16,
#   'duration': 4.12},
#  {'text': "book like oh what if people don't like",
#   'start': 424.639,
#   'duration': 3.041},
#  {'text': 'it what if the reviews are bad what if',
#   'start': 426.28,
#   'duration': 3.08},
#  {'text': "it's like why would anyone care",
#   'start': 427.68,
#   'duration': 3.84},
#  {'text': 'what I have to say all of these feelings',
#   'start': 429.36,
#   'duration': 5.559},
#  {'text': 'around fear really block me and then I',
#   'start': 431.52,
#   'duration': 6.2},
#  {'text': 'would feel the negative emotion come up',
#   'start': 434.919,
#   'duration': 3.921},
#  {'text': "sometimes I'd be aware of it other times",
#   'start': 437.72,
#   'duration': 2.68},
#  {'text': "I won't be aware of it and it would just",
#   'start': 438.84,
#   'duration': 4.16},
#  {'text': 'be easier to soothe Myself by opening up',
#   'start': 440.4,
#   'duration': 3.88},
#  {'text': 'my phone or going on YouTube and', 'start': 443.0, 'duration': 3.4},
#  {'text': 'watching asmin gold TV doing a video iay',
#   'start': 444.28,
#   'duration': 3.319},
#  {'text': 'about World of Warcraft or something',
#   'start': 446.4,
#   'duration': 2.519},
#  {'text': "like that I wasn't acknowledging the",
#   'start': 447.599,
#   'duration': 3.28},
#  {'text': 'fact that really the reason I was',
#   'start': 448.919,
#   'duration': 3.12},
#  {'text': 'getting distracted was because I was',
#   'start': 450.879,
#   'duration': 3.241},
#  {'text': 'avoiding this feeling of fear this',
#   'start': 452.039,
#   'duration': 3.361},
#  {'text': 'feeling of anxiety and then this feeling',
#   'start': 454.12,
#   'duration': 4.56},
#  {'text': 'of self-doubt and you know the the hack',
#   'start': 455.4,
#   'duration': 5.359},
#  {'text': "I found for this was you know there's",
#   'start': 458.68,
#   'duration': 3.359},
#  {'text': 'various hacks that Writers come up with',
#   'start': 460.759,
#   'duration': 2.84},
#  {'text': 'to overcome this righteous block because',
#   'start': 462.039,
#   'duration': 3.641},
#  {'text': 'writers block is fundamentally like some',
#   'start': 463.599,
#   'duration': 3.56},
#  {'text': "sort of feeling that we're that we're",
#   'start': 465.68,
#   'duration': 3.239},
#  {'text': 'struggling to deal with but one way I',
#   'start': 467.159,
#   'duration': 3.121},
#  {'text': 'found to deal with that was just the',
#   'start': 468.919,
#   'duration': 4.081},
#  {'text': "idea of fast bad wrong FBR and it's like",
#   'start': 470.28,
#   'duration': 4.12},
#  {'text': 'if the goal is to make something fast',
#   'start': 473.0,
#   'duration': 4.08},
#  {'text': 'and bad and wrong then great yeah I I',
#   'start': 474.4,
#   'duration': 3.88},
#  {'text': 'have pretty high confidence in my',
#   'start': 477.08,
#   'duration': 2.6},
#  {'text': 'ability to make something fast bad and',
#   'start': 478.28,
#   'duration': 3.0},
#  {'text': 'wrong and therefore the negative emotion',
#   'start': 479.68,
#   'duration': 3.4},
#  {'text': "goes away I've also got a bunch of",
#   'start': 481.28,
#   'duration': 3.12},
#  {'text': 'strategies in chapter 5 of my book',
#   'start': 483.08,
#   'duration': 2.76},
#  {'text': 'around like how we can overcome the',
#   'start': 484.4,
#   'duration': 3.479},
#  {'text': 'negative emotion of fear but like that',
#   'start': 485.84,
#   'duration': 4.12},
#  {'text': 'is a big part of why we get distracted',
#   'start': 487.879,
#   'duration': 3.641},
#  {'text': 'because there is some sort of anxiety or',
#   'start': 489.96,
#   'duration': 2.959},
#  {'text': "self-doubt that we're feeling the second",
#   'start': 491.52,
#   'duration': 3.16},
#  {'text': 'big part of why why we get distracted is',
#   'start': 492.919,
#   'duration': 3.361},
#  {'text': "because the task that we're trying to do",
#   'start': 494.68,
#   'duration': 3.04},
#  {'text': 'is just really really really boring',
#   'start': 496.28,
#   'duration': 3.16},
#  {'text': 'unfortunately we all have to do things',
#   'start': 497.72,
#   'duration': 3.52},
#  {'text': 'at times that are not that are kind of',
#   'start': 499.44,
#   'duration': 4.56},
#  {'text': 'boring the trick here is something that',
#   'start': 501.24,
#   'duration': 5.56},
#  {'text': 'I have on my phone my phone wallpaper if',
#   'start': 504.0,
#   'duration': 3.919},
#  {'text': 'this', 'start': 506.8, 'duration': 3.64},
#  {'text': 'focuses What would this look like if it',
#   'start': 507.919,
#   'duration': 4.401},
#  {'text': 'were fun I have it on my phone these',
#   'start': 510.44,
#   'duration': 3.56},
#  {'text': 'days normally I have it as a Post-It',
#   'start': 512.32,
#   'duration': 3.44},
#  {'text': 'note on my computer monitor what would',
#   'start': 514.0,
#   'duration': 3.32},
#  {'text': 'this look like if it were fun how do you',
#   'start': 515.76,
#   'duration': 3.0},
#  {'text': 'make your work feel good how do you make',
#   'start': 517.32,
#   'duration': 2.399},
#  {'text': 'it enjoyable and how do you make it',
#   'start': 518.76,
#   'duration': 2.279},
#  {'text': 'energizing in the book we talk about',
#   'start': 519.719,
#   'duration': 2.88},
#  {'text': 'play and power and people these are the',
#   'start': 521.039,
#   'duration': 3.12},
#  {'text': 'three PS that we can apply to whatever',
#   'start': 522.599,
#   'duration': 3.081},
#  {'text': "work we're doing to make it more fun",
#   'start': 524.159,
#   'duration': 2.921},
#  {'text': 'because if the thing is a little bit',
#   'start': 525.68,
#   'duration': 3.4},
#  {'text': 'more enjoyable then you are a lot less',
#   'start': 527.08,
#   'duration': 4.0},
#  {'text': 'likely to get distracted by the thing oh',
#   'start': 529.08,
#   'duration': 3.199},
#  {'text': "and by the way if you're interested in",
#   'start': 531.08,
#   'duration': 2.96},
#  {'text': 'learning more about what near says in',
#   'start': 532.279,
#   'duration': 3.281},
#  {'text': 'the book indistractable you should read',
#   'start': 534.04,
#   'duration': 2.56},
#  {'text': "the book but if you don't want to read",
#   'start': 535.56,
#   'duration': 2.32},
#  {'text': 'the book you can absolutely check out',
#   'start': 536.6,
#   'duration': 2.88},
#  {'text': 'the summary of that book over on short',
#   'start': 537.88,
#   'duration': 3.12},
#  {'text': "form they're not sponsoring this video",
#   'start': 539.48,
#   'duration': 2.64},
#  {'text': 'but I do have an affiliate link down',
#   'start': 541.0,
#   'duration': 2.959},
#  {'text': 'below they even have a summary of my',
#   'start': 542.12,
#   'duration': 3.36},
#  {'text': "book so if for whatever reason you don't",
#   'start': 543.959,
#   'duration': 3.041},
#  {'text': "want to read this and you'd rather read",
#   'start': 545.48,
#   'duration': 2.96},
#  {'text': 'a book summary of it you can check it',
#   'start': 547.0,
#   'duration': 3.24},
#  {'text': "out on short form uh there's a link down",
#   'start': 548.44,
#   'duration': 3.12},
#  {'text': "below it's an affiliate link but it does",
#   'start': 550.24,
#   'duration': 3.08},
#  {'text': 'also give you 20% discount if you feel',
#   'start': 551.56,
#   'duration': 3.04},
#  {'text': "like reading book summaries it's my",
#   'start': 553.32,
#   'duration': 2.68},
#  {'text': 'favorite source of book summaries all',
#   'start': 554.6,
#   'duration': 2.6},
#  {'text': 'right now we come to mistake number',
#   'start': 556.0,
#   'duration': 4.16},
#  {'text': 'three and the way we understand this is',
#   'start': 557.2,
#   'duration': 5.319},
#  {'text': 'a psychological concept called attention',
#   'start': 560.16,
#   'duration': 3.84},
#  {'text': 'residue now this is a term that was',
#   'start': 562.519,
#   'duration': 3.44},
#  {'text': 'introduced by Professor Sophie Leroy at',
#   'start': 564.0,
#   'duration': 3.6},
#  {'text': 'the University of Washington in a paper',
#   'start': 565.959,
#   'duration': 4.12},
#  {'text': 'published in 2009 now in her work Sophie',
#   'start': 567.6,
#   'duration': 4.359},
#  {'text': 'shows that when you switch from task a',
#   'start': 570.079,
#   'duration': 4.361},
#  {'text': "to task B your attention doesn't",
#   'start': 571.959,
#   'duration': 4.44},
#  {'text': 'instantly follow there is a residue of',
#   'start': 574.44,
#   'duration': 4.2},
#  {'text': 'your focus that stays stuck on task a',
#   'start': 576.399,
#   'duration': 4.161},
#  {'text': 'and this residue on the previous task',
#   'start': 578.64,
#   'duration': 3.639},
#  {'text': 'can completely ruin your performance on',
#   'start': 580.56,
#   'duration': 3.36},
#  {'text': 'the current task because your brain is',
#   'start': 582.279,
#   'duration': 3.601},
#  {'text': 'not yet fully transitioned to the next',
#   'start': 583.92,
#   'duration': 3.44},
#  {'text': 'task and really the thing is that our',
#   'start': 585.88,
#   'duration': 3.88},
#  {'text': 'brains are not designed to keep parallel',
#   'start': 587.36,
#   'duration': 4.52},
#  {'text': 'tracks of attention going it is a lot',
#   'start': 589.76,
#   'duration': 3.92},
#  {'text': 'easier for us to focus on one thing at a',
#   'start': 591.88,
#   'duration': 3.959},
#  {'text': 'time rather than try and sort of split',
#   'start': 593.68,
#   'duration': 4.159},
#  {'text': 'our Focus across multiple things and so',
#   'start': 595.839,
#   'duration': 3.68},
#  {'text': 'switching between many different tasks',
#   'start': 597.839,
#   'duration': 3.68},
#  {'text': 'within a work block might make you feel',
#   'start': 599.519,
#   'duration': 3.601},
#  {'text': "like you're doing a lot of work but it",
#   'start': 601.519,
#   'duration': 2.88},
#  {'text': 'can actually be really counterproductive',
#   'start': 603.12,
#   'duration': 2.839},
#  {'text': 'and cause you to get distracted and so',
#   'start': 604.399,
#   'duration': 3.0},
#  {'text': 'the key lesson here is when you are',
#   'start': 605.959,
#   'duration': 4.32},
#  {'text': 'doing something do one thing at a time',
#   'start': 607.399,
#   'duration': 5.12},
#  {'text': 'trying to work on your writing and also',
#   'start': 610.279,
#   'duration': 3.881},
#  {'text': 'reply to slack messages and also reply',
#   'start': 612.519,
#   'duration': 2.921},
#  {'text': 'to this email and also work on this',
#   'start': 614.16,
#   'duration': 2.4},
#  {'text': "other design task that you're doing at",
#   'start': 615.44,
#   'duration': 2.44},
#  {'text': "the same time it's just not going to",
#   'start': 616.56,
#   'duration': 2.719},
#  {'text': 'work like trying to do things in',
#   'start': 617.88,
#   'duration': 2.92},
#  {'text': 'parallel generally is a lot less',
#   'start': 619.279,
#   'duration': 2.961},
#  {'text': 'efficient and a lot less effective than',
#   'start': 620.8,
#   'duration': 3.08},
#  {'text': 'trying to do things in series I.E just',
#   'start': 622.24,
#   'duration': 3.36},
#  {'text': 'one at a time practical thing here is',
#   'start': 623.88,
#   'duration': 3.72},
#  {'text': 'for example turn off notifications turn',
#   'start': 625.6,
#   'duration': 3.4},
#  {'text': 'on the focus mode on your phone and on',
#   'start': 627.6,
#   'duration': 3.32},
#  {'text': 'all your devices I have the feature on',
#   'start': 629.0,
#   'duration': 3.6},
#  {'text': 'on my Apple devices that shares Focus',
#   'start': 630.92,
#   'duration': 3.56},
#  {'text': "mode between devices so I'm not even",
#   'start': 632.6,
#   'duration': 3.44},
#  {'text': 'going to see notifications if they pop',
#   'start': 634.48,
#   'duration': 3.799},
#  {'text': 'up I always have my phone face down on',
#   'start': 636.04,
#   'duration': 3.4},
#  {'text': "the table in front of me so that I don't",
#   'start': 638.279,
#   'duration': 2.521},
#  {'text': 'even see the notifications and just',
#   'start': 639.44,
#   'duration': 2.839},
#  {'text': 'before filming this video I opened up',
#   'start': 640.8,
#   'duration': 3.159},
#  {'text': 'slack and I saw that I had about 18',
#   'start': 642.279,
#   'duration': 3.36},
#  {'text': 'unright messages on slack that I got I',
#   'start': 643.959,
#   'duration': 3.521},
#  {'text': 'was tagged in and I was thinking you',
#   'start': 645.639,
#   'duration': 3.841},
#  {'text': "know what that's fine I'm not even going",
#   'start': 647.48,
#   'duration': 3.72},
#  {'text': 'to look at them because I just know that',
#   'start': 649.48,
#   'duration': 4.24},
#  {'text': 'if I even look at those 1800 messages',
#   'start': 651.2,
#   'duration': 3.72},
#  {'text': "it's going to cause some sort of",
#   'start': 653.72,
#   'duration': 2.4},
#  {'text': "attention residue it's going to cause me",
#   'start': 654.92,
#   'duration': 2.24},
#  {'text': "to lose focus it's going to get me",
#   'start': 656.12,
#   'duration': 2.56},
#  {'text': 'distracted sometimes what I like to do',
#   'start': 657.16,
#   'duration': 2.96},
#  {'text': 'is in the middle of day like like maybe',
#   'start': 658.68,
#   'duration': 2.64},
#  {'text': 'after having lunch or something where',
#   'start': 660.12,
#   'duration': 2.64},
#  {'text': "I've got half an hour of like empty",
#   'start': 661.32,
#   'duration': 3.04},
#  {'text': 'empty time before the next meeting or',
#   'start': 662.76,
#   'duration': 3.48},
#  {'text': "whatever I'll use that time to do the",
#   'start': 664.36,
#   'duration': 3.24},
#  {'text': 'shallow work to just kind of go through',
#   'start': 666.24,
#   'duration': 2.599},
#  {'text': 'WhatsApp and reply to things and just',
#   'start': 667.6,
#   'duration': 2.88},
#  {'text': 'generally wander around somewhat',
#   'start': 668.839,
#   'duration': 3.081},
#  {'text': 'aimlessly kind of replying to stuff here',
#   'start': 670.48,
#   'duration': 4.799},
#  {'text': "and there and that's fine but it's fine",
#   'start': 671.92,
#   'duration': 4.8},
#  {'text': "because that's sort of the intention",
#   'start': 675.279,
#   'duration': 2.881},
#  {'text': "that I've made for that particular block",
#   'start': 676.72,
#   'duration': 3.239},
#  {'text': 'of time the more intentional we can be',
#   'start': 678.16,
#   'duration': 2.88},
#  {'text': 'with the blocks of time that we have in',
#   'start': 679.959,
#   'duration': 2.841},
#  {'text': 'our calendar and and in our life the',
#   'start': 681.04,
#   'duration': 3.28},
#  {'text': 'more likely we are to actually make time',
#   'start': 682.8,
#   'duration': 2.92},
#  {'text': 'for the things that really matter to us',
#   'start': 684.32,
#   'duration': 2.72},
#  {'text': "oh by the way if you're enjoying this",
#   'start': 685.72,
#   'duration': 2.72},
#  {'text': 'video so far then you might like to',
#   'start': 687.04,
#   'duration': 3.76},
#  {'text': 'check out my completely free 7-Day Focus',
#   'start': 688.44,
#   'duration': 4.44},
#  {'text': "crash course it's at Focus crashcourse",
#   'start': 690.8,
#   'duration': 3.32},
#  {'text': "tocom it's completely free you enter",
#   'start': 692.88,
#   'duration': 2.8},
#  {'text': 'your email and then every day for 7 days',
#   'start': 694.12,
#   'duration': 2.68},
#  {'text': "I'll send you an email that has some",
#   'start': 695.68,
#   'duration': 2.36},
#  {'text': 'principles and strategies and', 'start': 696.8, 'duration': 3.279},
#  {'text': 'evidence-based tips on how to become',
#   'start': 698.04,
#   'duration': 4.039},
#  {'text': 'more focused so completely free check it',
#   'start': 700.079,
#   'duration': 3.401},
#  {'text': "out all right let's talk about mistake",
#   'start': 702.079,
#   'duration': 3.2},
#  {'text': 'number four now so when I was doing the',
#   'start': 703.48,
#   'duration': 4.96},
#  {'text': 'research for my book there was a tech',
#   'start': 705.279,
#   'duration': 4.761},
#  {'text': 'company that I discovered called the',
#   'start': 708.44,
#   'duration': 4.079},
#  {'text': 'drum group and basically this company',
#   'start': 710.04,
#   'duration': 4.64},
#  {'text': 'wanted to find out what made their most',
#   'start': 712.519,
#   'duration': 3.56},
#  {'text': 'productive employees different from',
#   'start': 714.68,
#   'duration': 2.8},
#  {'text': 'their least productive employees',
#   'start': 716.079,
#   'duration': 2.641},
#  {'text': 'basically what they found was that the',
#   'start': 717.48,
#   'duration': 3.84},
#  {'text': 'most productive employees worked Less',
#   'start': 718.72,
#   'duration': 4.28},
#  {'text': 'hours and took more breaks than the',
#   'start': 721.32,
#   'duration': 3.04},
#  {'text': 'least productive employees and so what',
#   'start': 723.0,
#   'duration': 2.8},
#  {'text': 'they did was they used a Time tracking',
#   'start': 724.36,
#   'duration': 2.599},
#  {'text': 'app that they installed in all their',
#   'start': 725.8,
#   'duration': 2.8},
#  {'text': "people's devices and stuff and they",
#   'start': 726.959,
#   'duration': 3.601},
#  {'text': 'founded the group Elite workers I.E the',
#   'start': 728.6,
#   'duration': 4.239},
#  {'text': 'top 10% in terms of productivity they',
#   'start': 730.56,
#   'duration': 4.279},
#  {'text': 'worked intensely for 52 minutes on',
#   'start': 732.839,
#   'duration': 3.36},
#  {'text': 'average and then they would take the',
#   'start': 734.839,
#   'duration': 4.041},
#  {'text': 'next 17 minutes off and within those 52',
#   'start': 736.199,
#   'duration': 4.481},
#  {'text': 'minutes they were doing intense focused',
#   'start': 738.88,
#   'duration': 3.639},
#  {'text': 'deep work single tasking focusing on',
#   'start': 740.68,
#   'duration': 4.0},
#  {'text': 'just one thing and then in the next 17',
#   'start': 742.519,
#   'duration': 3.961},
#  {'text': 'minutes these guys were really resting',
#   'start': 744.68,
#   'duration': 3.159},
#  {'text': "so they weren't really checking slack or",
#   'start': 746.48,
#   'duration': 2.719},
#  {'text': 'like looking at email every 5 minutes',
#   'start': 747.839,
#   'duration': 2.961},
#  {'text': 'they were actively taking a break during',
#   'start': 749.199,
#   'duration': 3.2},
#  {'text': 'that time and I really like having these',
#   'start': 750.8,
#   'duration': 3.36},
#  {'text': "two numbers in mind 52 and 17 they're",
#   'start': 752.399,
#   'duration': 3.12},
#  {'text': 'kind of weird numbers like you know I',
#   'start': 754.16,
#   'duration': 2.679},
#  {'text': 'wish there was there probably a better',
#   'start': 755.519,
#   'duration': 2.88},
#  {'text': "way of like I don't know 50 and 15 or",
#   'start': 756.839,
#   'duration': 4.56},
#  {'text': 'something but 5217 is like a pretty',
#   'start': 758.399,
#   'duration': 5.641},
#  {'text': 'reasonable ratio of work to break time',
#   'start': 761.399,
#   'duration': 4.44},
#  {'text': 'and I certainly find for myself whenever',
#   'start': 764.04,
#   'duration': 4.359},
#  {'text': "I'm working on something I have like a",
#   'start': 765.839,
#   'duration': 3.521},
#  {'text': 'Lord of the Rings music in the',
#   'start': 768.399,
#   'duration': 2.641},
#  {'text': 'background and I can see how much time',
#   'start': 769.36,
#   'duration': 3.52},
#  {'text': 'has elapsed in the three-hour playlist',
#   'start': 771.04,
#   'duration': 3.919},
#  {'text': 'and usually by the time it gets to 40 50',
#   'start': 772.88,
#   'duration': 4.959},
#  {'text': 'minutes I start to feel myself itching',
#   'start': 774.959,
#   'duration': 4.44},
#  {'text': 'to do something else itching to get',
#   'start': 777.839,
#   'duration': 2.641},
#  {'text': 'distracted and like wanting to check',
#   'start': 779.399,
#   'duration': 2.56},
#  {'text': 'emails and stuff and then I look at the',
#   'start': 780.48,
#   'duration': 3.599},
#  {'text': "timer and I'm like oh okay it's been 48",
#   'start': 781.959,
#   'duration': 3.961},
#  {'text': "minutes now it's time to take a break",
#   'start': 784.079,
#   'duration': 2.76},
#  {'text': "okay so there's a couple of different",
#   'start': 785.92,
#   'duration': 2.64},
#  {'text': 'ways that we can apply this Insight one',
#   'start': 786.839,
#   'duration': 3.921},
#  {'text': 'way of doing it is by setting yourself',
#   'start': 788.56,
#   'duration': 3.839},
#  {'text': 'an intention that for the next 45',
#   'start': 790.76,
#   'duration': 3.199},
#  {'text': 'minutes or 50 minutes or 30 minutes or',
#   'start': 792.399,
#   'duration': 3.56},
#  {'text': 'hour like you time block a certain',
#   'start': 793.959,
#   'duration': 3.921},
#  {'text': 'amount of time where you intend to be',
#   'start': 795.959,
#   'duration': 3.841},
#  {'text': "focused on that one task and you don't",
#   'start': 797.88,
#   'duration': 4.16},
#  {'text': 'deviate from that task during that time',
#   'start': 799.8,
#   'duration': 4.68},
#  {'text': "for me personally I don't really like",
#   'start': 802.04,
#   'duration': 4.96},
#  {'text': 'that style approach where I sort of fix',
#   'start': 804.48,
#   'duration': 4.799},
#  {'text': 'fixedly like give myself a fixed amount',
#   'start': 807.0,
#   'duration': 3.76},
#  {'text': 'of time to do the thing un unless I have',
#   'start': 809.279,
#   'duration': 2.601},
#  {'text': 'like a meeting coming up or something',
#   'start': 810.76,
#   'duration': 2.519},
#  {'text': 'that I have to do in which case',
#   'start': 811.88,
#   'duration': 2.48},
#  {'text': "obviously I'll give myself a fixed",
#   'start': 813.279,
#   'duration': 2.721},
#  {'text': 'amount of time generally what I prefer',
#   'start': 814.36,
#   'duration': 3.279},
#  {'text': 'to do is I prefer to whack on the Lord',
#   'start': 816.0,
#   'duration': 3.56},
#  {'text': 'of the Ring soundtrack and then I just',
#   'start': 817.639,
#   'duration': 5.081},
#  {'text': 'work for as long as it takes me to feel',
#   'start': 819.56,
#   'duration': 4.839},
#  {'text': 'as if I can just make full full Focus',
#   'start': 822.72,
#   'duration': 2.96},
#  {'text': 'progress on that one task whatever the',
#   'start': 824.399,
#   'duration': 3.161},
#  {'text': "thing I'm doing is and then when I do",
#   'start': 825.68,
#   'duration': 3.839},
#  {'text': 'find myself getting distracted or like',
#   'start': 827.56,
#   'duration': 3.44},
#  {'text': "wanting to do something else I'll look",
#   'start': 829.519,
#   'duration': 3.641},
#  {'text': "at the timer and I'll see okay cool 38",
#   'start': 831.0,
#   'duration': 3.72},
#  {'text': "minutes of past that's fine it's time to",
#   'start': 833.16,
#   'duration': 3.119},
#  {'text': 'take a break and I sort of recognize',
#   'start': 834.72,
#   'duration': 3.88},
#  {'text': 'that feeling Within Myself that when I',
#   'start': 836.279,
#   'duration': 4.281},
#  {'text': 'feel the need to do something else that',
#   'start': 838.6,
#   'duration': 3.32},
#  {'text': 'is when it is a very good time to take a',
#   'start': 840.56,
#   'duration': 3.32},
#  {'text': 'break to get up to make a coffee to do a',
#   'start': 841.92,
#   'duration': 3.719},
#  {'text': 'Wii to do whatever the thing is and the',
#   'start': 843.88,
#   'duration': 3.079},
#  {'text': 'key thing to remember is that the thing',
#   'start': 845.639,
#   'duration': 3.401},
#  {'text': 'that you do during the break should not',
#   'start': 846.959,
#   'duration': 4.521},
#  {'text': 'generate any additional obligations',
#   'start': 849.04,
#   'duration': 4.12},
#  {'text': 'because if for example you use your',
#   'start': 851.48,
#   'duration': 3.76},
#  {'text': 'brakes to check your messages now',
#   'start': 853.16,
#   'duration': 3.479},
#  {'text': 'checking messages is going to generate a',
#   'start': 855.24,
#   'duration': 2.719},
#  {'text': 'bunch of random tasks for you to do and',
#   'start': 856.639,
#   'duration': 2.281},
#  {'text': "then that's going to cause you to get",
#   'start': 857.959,
#   'duration': 2.161},
#  {'text': 'distracted from the thing that you are',
#   'start': 858.92,
#   'duration': 3.159},
#  {'text': 'actually trying to do next so take a',
#   'start': 860.12,
#   'duration': 3.44},
#  {'text': 'break take a proper break do something',
#   'start': 862.079,
#   'duration': 2.921},
#  {'text': 'that does not generate any additional',
#   'start': 863.56,
#   'duration': 3.199},
#  {'text': 'obligations and tasks on your time',
#   'start': 865.0,
#   'duration': 3.36},
#  {'text': 'ideally and now we come to mistake',
#   'start': 866.759,
#   'duration': 3.64},
#  {'text': 'number five and and for most of this',
#   'start': 868.36,
#   'duration': 3.2},
#  {'text': "video actually for all this video we've",
#   'start': 870.399,
#   'duration': 2.921},
#  {'text': 'been talking about software problems',
#   'start': 871.56,
#   'duration': 3.839},
#  {'text': 'problems with you know the way that we',
#   'start': 873.32,
#   'duration': 3.28},
#  {'text': 'respond to things in our brain or the',
#   'start': 875.399,
#   'duration': 2.761},
#  {'text': 'way that we operate this is problems',
#   'start': 876.6,
#   'duration': 3.72},
#  {'text': 'with the software but one of the biggest',
#   'start': 878.16,
#   'duration': 3.679},
#  {'text': 'things that ruins our focus and causes',
#   'start': 880.32,
#   'duration': 3.28},
#  {'text': 'us to get distracted is problems with',
#   'start': 881.839,
#   'duration': 4.841},
#  {'text': 'our Hardware I.E our body and our brain',
#   'start': 883.6,
#   'duration': 5.84},
#  {'text': 'in terms of diet and exercise and in',
#   'start': 886.68,
#   'duration': 4.68},
#  {'text': 'particular sleep this is the stuff',
#   'start': 889.44,
#   'duration': 3.12},
#  {'text': 'everyone already knows you should be',
#   'start': 891.36,
#   'duration': 2.96},
#  {'text': 'sleeping 8 hours a night you should be',
#   'start': 892.56,
#   'duration': 3.12},
#  {'text': 'eating healthy food we all know what',
#   'start': 894.32,
#   'duration': 3.079},
#  {'text': "healthy food is eat like an adult don't",
#   'start': 895.68,
#   'duration': 3.48},
#  {'text': 'eat like a child we should be doing',
#   'start': 897.399,
#   'duration': 3.921},
#  {'text': 'exercise every day ideally I found it',
#   'start': 899.16,
#   'duration': 3.76},
#  {'text': 'incredibly helpful just going to the gym',
#   'start': 901.32,
#   'duration': 2.92},
#  {'text': 'first thing in the morning so for',
#   'start': 902.92,
#   'duration': 2.8},
#  {'text': 'example this morning from 8:00 till 9:00',
#   'start': 904.24,
#   'duration': 3.32},
#  {'text': 'a.m. I had a gym session and yesterday',
#   'start': 905.72,
#   'duration': 3.2},
#  {'text': 'was leg day and the day before that',
#   'start': 907.56,
#   'duration': 3.32},
#  {'text': 'which was was chess day and I find that',
#   'start': 908.92,
#   'duration': 3.4},
#  {'text': 'going to the gym four or five times a',
#   'start': 910.88,
#   'duration': 3.0},
#  {'text': 'week in the mornings is incredibly',
#   'start': 912.32,
#   'duration': 3.12},
#  {'text': 'helpful for my energy levels and for my',
#   'start': 913.88,
#   'duration': 3.28},
#  {'text': 'ability to not get distracted during the',
#   'start': 915.44,
#   'duration': 3.88},
#  {'text': "day unfortunately I didn't get much",
#   'start': 917.16,
#   'duration': 3.44},
#  {'text': 'sleep last night because I was watching',
#   'start': 919.32,
#   'duration': 2.959},
#  {'text': 'Dune po 2 and then I got home at like',
#   'start': 920.6,
#   'duration': 3.479},
#  {'text': 'midnight and then my mind was buzzing',
#   'start': 922.279,
#   'duration': 3.041},
#  {'text': 'because I watched a few video essays',
#   'start': 924.079,
#   'duration': 3.081},
#  {'text': 'about like how Dune part 2 was made and',
#   'start': 925.32,
#   'duration': 2.999},
#  {'text': 'then I was buzzing with all the things',
#   'start': 927.16,
#   'duration': 2.679},
#  {'text': 'and I was like oh okay damn you know my',
#   'start': 928.319,
#   'duration': 3.801},
#  {'text': "brain's on got I've got to wake up for",
#   'start': 929.839,
#   'duration': 4.641},
#  {'text': 'the gym at 7:30 damn sleep time is cut',
#   'start': 932.12,
#   'duration': 4.0},
#  {'text': 'down and I was like okay cool I need to',
#   'start': 934.48,
#   'duration': 3.76},
#  {'text': "meditate and so I didn't get my 8 hours",
#   'start': 936.12,
#   'duration': 3.399},
#  {'text': 'of sleep unfortunately which is why',
#   'start': 938.24,
#   'duration': 2.68},
#  {'text': "today I know I'm more likely to have",
#   'start': 939.519,
#   'duration': 3.081},
#  {'text': 'issues as as it relates to focus and',
#   'start': 940.92,
#   'duration': 3.24},
#  {'text': 'getting distracted which means I need to',
#   'start': 942.6,
#   'duration': 3.599},
#  {'text': 'be even more on my aame and just really',
#   'start': 944.16,
#   'duration': 4.32},
#  {'text': 'focus on building that plan not falling',
#   'start': 946.199,
#   'duration': 4.041},
#  {'text': 'into these other software mistakes to',
#   'start': 948.48,
#   'duration': 3.719},
#  {'text': "make up for the fact that I've had only",
#   'start': 950.24,
#   'duration': 3.48},
#  {'text': 'like 4 and a half hours of sleep last',
#   'start': 952.199,
#   'duration': 2.64},
#  {'text': 'night because I was watching videos',
#   'start': 953.72,
#   'duration': 2.679},
#  {'text': 'about June part two it becomes a lot',
#   'start': 954.839,
#   'duration': 3.0},
#  {'text': 'easier to stay focused and not get',
#   'start': 956.399,
#   'duration': 3.24},
#  {'text': 'distracted when you have taken care of',
#   'start': 957.839,
#   'duration': 3.36},
#  {'text': "the hardware stuff so if you're not",
#   'start': 959.639,
#   'duration': 3.361},
#  {'text': "sleeping if you're eating like crap and",
#   'start': 961.199,
#   'duration': 3.681},
#  {'text': "if you're not getting exercise of course",
#   'start': 963.0,
#   'duration': 3.16},
#  {'text': "you're going to struggle to focus like",
#   'start': 964.88,
#   'duration': 3.16},
#  {'text': "you can't expect to be able to focus if",
#   'start': 966.16,
#   'duration': 3.359},
#  {'text': 'this hardware and if your health is',
#   'start': 968.04,
#   'duration': 3.239},
#  {'text': 'absolutely terrible so often when it',
#   'start': 969.519,
#   'duration': 3.921},
#  {'text': 'comes to software problems you kind of',
#   'start': 971.279,
#   'duration': 3.36},
#  {'text': 'want to deal with the hardware stuff',
#   'start': 973.44,
#   'duration': 2.639},
#  {'text': 'first one thing that my friend s Bloom',
#   'start': 974.639,
#   'duration': 3.281},
#  {'text': 'often says is that you know there is no',
#   'start': 976.079,
#   'duration': 3.401},
#  {'text': 'such thing as a loser who wakes up at',
#   'start': 977.92,
#   'duration': 3.12},
#  {'text': '5:00 a.m. and does a workout you know',
#   'start': 979.48,
#   'duration': 2.64},
#  {'text': 'when I first heard him say that I was',
#   'start': 981.04,
#   'duration': 3.08},
#  {'text': 'like huh are you saying everyone has to',
#   'start': 982.12,
#   'duration': 3.279},
#  {'text': "wake up at 5:00 a.m. it's like that's",
#   'start': 984.12,
#   'duration': 2.24},
#  {'text': "not what he's saying what he's saying is",
#   'start': 985.399,
#   'duration': 2.88},
#  {'text': 'that if you wake up an hour earlier and',
#   'start': 986.36,
#   'duration': 3.479},
#  {'text': 'just exercise', 'start': 988.279, 'duration': 4.161},
#  {'text': 'you are going to be taking care of',
#   'start': 989.839,
#   'duration': 5.8},
#  {'text': 'yourself in a way that you might not be',
#   'start': 992.44,
#   'duration': 5.319},
#  {'text': 'doing otherwise and that actually bleeds',
#   'start': 995.639,
#   'duration': 4.161},
#  {'text': 'into all of the other areas of your life',
#   'start': 997.759,
#   'duration': 4.32},
#  {'text': 'and really helps you to stay focused and',
#   'start': 999.8,
#   'duration': 4.08},
#  {'text': 'avoid distraction this is why every',
#   'start': 1002.079,
#   'duration': 3.641},
#  {'text': "single highflying CEO I've ever spoken",
#   'start': 1003.88,
#   'duration': 4.0},
#  {'text': 'to works out first thing in the morning',
#   'start': 1005.72,
#   'duration': 3.52},
#  {'text': 'but generally when I speak to people',
#   'start': 1007.88,
#   'duration': 3.6},
#  {'text': 'when at events and talks that I do if',
#   'start': 1009.24,
#   'duration': 3.48},
#  {'text': 'someone comes up to me and says that',
#   'start': 1011.48,
#   'duration': 2.839},
#  {'text': 'they struggle with distraction or they',
#   'start': 1012.72,
#   'duration': 3.039},
#  {'text': 'struggle with staying focused and I have',
#   'start': 1014.319,
#   'duration': 3.0},
#  {'text': 'time to talk to them about a few things',
#   'start': 1015.759,
#   'duration': 2.721},
#  {'text': "usually I find out that they're not",
#   'start': 1017.319,
#   'duration': 2.44},
#  {'text': "exercising they're not eating",
#   'start': 1018.48,
#   'duration': 2.039},
#  {'text': "particularly well and they're not",
#   'start': 1019.759,
#   'duration': 2.361},
#  {'text': 'sleeping particularly well so in that',
#   'start': 1020.519,
#   'duration': 2.921},
#  {'text': "case of course you're going to struggle",
#   'start': 1022.12,
#   'duration': 2.4},
#  {'text': "with focus and of course you're going to",
#   'start': 1023.44,
#   'duration': 3.8},
#  {'text': 'get distracted so I would say the thing',
#   'start': 1024.52,
#   'duration': 3.84},
#  {'text': 'to keep in mind and the thing that I',
#   'start': 1027.24,
#   'duration': 3.24},
#  {'text': 'like to keep on reminding myself is that',
#   'start': 1028.36,
#   'duration': 3.12},
#  {'text': 'yes we can have all these software',
#   'start': 1030.48,
#   'duration': 2.28},
#  {'text': 'issues yes we can install all the apps',
#   'start': 1031.48,
#   'duration': 2.52},
#  {'text': 'in the world and use the focus modes and',
#   'start': 1032.76,
#   'duration': 3.159},
#  {'text': 'all that kind of stuff but without the',
#   'start': 1034.0,
#   'duration': 3.799},
#  {'text': 'hardware without our body and our mind',
#   'start': 1035.919,
#   'duration': 3.601},
#  {'text': "being in tiptop shape it's going to be",
#   'start': 1037.799,
#   'duration': 3.4},
#  {'text': 'really hard to do all this stuff but if',
#   'start': 1039.52,
#   'duration': 3.6},
#  {'text': 'our body and mind is in tiptop shape it',
#   'start': 1041.199,
#   'duration': 3.76},
#  {'text': 'becomes a lot easier to do all of these',
#   'start': 1043.12,
#   'duration': 3.079},
#  {'text': 'things that we want to do okay so',
#   'start': 1044.959,
#   'duration': 2.201},
#  {'text': 'hopefully you got something from this',
#   'start': 1046.199,
#   'duration': 2.081},
#  {'text': 'video I would love for you to leave a',
#   'start': 1047.16,
#   'duration': 3.04},
#  {'text': 'comment down below about one actionable',
#   'start': 1048.28,
#   'duration': 3.279},
#  {'text': "thing that you're going to do to apply",
#   'start': 1050.2,
#   'duration': 2.88},
#  {'text': 'in your life in order to not get',
#   'start': 1051.559,
#   'duration': 3.201},
#  {'text': 'distracted and to focus better and if',
#   'start': 1053.08,
#   'duration': 2.92},
#  {'text': "you're interested in hearing more this",
#   'start': 1054.76,
#   'duration': 2.56},
#  {'text': 'video is actually the first in a',
#   'start': 1056.0,
#   'duration': 2.919},
#  {'text': "three-part series that we're working on",
#   'start': 1057.32,
#   'duration': 3.64},
#  {'text': 'about how to be more focused because we',
#   'start': 1058.919,
#   'duration': 3.521},
#  {'text': 'realize that when we poll our audience',
#   'start': 1060.96,
#   'duration': 2.92},
#  {'text': 'and stuff that like everyone really',
#   'start': 1062.44,
#   'duration': 3.119},
#  {'text': "struggles with focus and so we're going",
#   'start': 1063.88,
#   'duration': 3.24},
#  {'text': 'to make more videos about it and video',
#   'start': 1065.559,
#   'duration': 2.801},
#  {'text': 'number two is going to be about some',
#   'start': 1067.12,
#   'duration': 2.439},
#  {'text': 'strategies and techniques that you can',
#   'start': 1068.36,
#   'duration': 2.84},
#  {'text': 'use and video number three is going to',
#   'start': 1069.559,
#   'duration': 3.921},
#  {'text': 'be about my favorite tools to stay more',
#   'start': 1071.2,
#   'duration': 3.959},
#  {'text': 'focused so those videos will be right',
#   'start': 1073.48,
#   'duration': 2.92},
#  {'text': 'over there in this little playlist that',
#   'start': 1075.159,
#   'duration': 2.52},
#  {'text': "I've created for you thank you so much",
#   'start': 1076.4,
#   'duration': 2.2},
#  {'text': 'for watching and see you in the next',
#   'start': 1077.679,
#   'duration': 4.24},
#  {'text': 'video bye-bye', 'start': 1078.6, 'duration': 3.319}]

# %%
transcript = YouTubeTranscriptApi.get_transcript(vid_id)

# %%
# to check if the video transcript has text or not
transcript[0:5]
# Out:
# [{'text': 'being able to not get distracted is',
#   'start': 0.04,
#   'duration': 5.239},
#  {'text': 'genuinely one of the most life-changing',
#   'start': 2.639,
#   'duration': 4.321},
#  {'text': 'skills if we want to improve our lives',
#   'start': 5.279,
#   'duration': 3.201},
#  {'text': 'in any way if we want to make progress',
#   'start': 6.96,
#   'duration': 3.16},
#  {'text': 'on our studies or in our work or in our',
#   'start': 8.48,
#   'duration': 3.52}]

# %%
# iterating throughout and adding all text together
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 23817

# %%
result
# Out:
# " being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way if we want to make progress on our studies or in our work or in our side hustle or even like being present with our families for goodness sake that all requires this magical ability called focus it requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing the thing is we are bombarded by distractions all the time we have our social media notifications pinging right left and Center we have messages and emails and whatsapps and text messages and it's like it's so easy to get distracted these days with all of the Endless Options that we have available to us and the reason why I think it's so incredibly important to cultivate the ability to focus and this is the thing that I've really realized over the years that the quality of my life is directly proportional to my ability to focus and I've had periods of my life where I've really really really struggled to focus my first year of med school for example was a year where I really struggled to focus I was burning the midnight oil feeling really overwhelmed feeling really really stressed and didn't even do that well in my exams but then as I started to research more about productivity you know reading papers about it doing an extra degree in Psychology as well I I sort of realized that there there actually are a bunch of different techniques that we can learn to help us focus better and if we can just learn and apply those techniques it massively boosts the quality of our life okay so in this video we're going to go over the five key mistakes that cause us to get distracted and to not be able to focus and let's start with mistake number one now there was one thing that I read that really made this mistake hit home for me and that was when I read near eel's book indestructible this is a book about how to be indestructible and how to avoid distractions and all that kind of fun stuff and we're probably going to do a video about it at some point but right at the start of the book he says something like really really profound which is that the opposite of distraction is traction and traction is when you are doing something intentionally to move you towards where you want to go and distraction is when you are doing something that takes you away from where you want to go but then the next thing he says is that in order to actually know what the thing is you want to do and what the thing is you want to avoid you have to actually have a plan cuz if you don't have a plan you can't be distracted because you never had a plan to begin with distraction happens when we are intending to do one thing and then we find ourselves doing something else and so mistake number one that we all make that I make all the time when I find myself getting distracted is just not having a plan when you don't have a plan and you sit down at your computer or on your phone with nothing in mind as to what you actually want to do that is when you're going to end up doing all the other small things this is kind of what social media platforms are designed for when you go on a social media platform you don't usually go on it with a particular goal in mind it's like someone who's just browsing I'm just going to go on YouTube and I'm going to see what's up I'm literally Outsourcing the decision of how I'm going to spend my time which is the single most valuable resource that I have I'm Outsourcing that decision to a team of thousands of developers whose in whose goal is to keep me on the platform for as long as possible and to serve me ads for as long as possible so that the platform can make money I like the team behind YouTube I've met some of them they're very nice people but like those are the incentives of these social media platforms so the key thing is that we need to make a plan in order to avoid getting distracted and the single  ...

# %% [markdown]
# ### **Generating Summary**
# ### Facebook Bart Large CNN Model

# %%
summarizerfb = pipeline("summarization", model="facebook/bart-large-cnn")
#sumd_text = summarizerfb(result, max_length=130, min_length=30, do_sample=False)

# %%
# iterating in batches since max token length for Bart models is 1024, so we divide each batch here into token lengths of <1000
num_iters = int(len(result)/1000)

# summarizing on each batch and appending to final summary
summarized_text = []
summarized_text2 = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizerfb(result[start:end], max_length=130, min_length=30, do_sample=False)
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)
  summarized_text2 = ' '.join(summarized_text)

# %%
len(result)

# %%
result
# Out:
# " this is the best piece of advice that I got recently if you're new here hello my name is Ali I'm a doctor turned entrepreneur and I'm the author of feel-good productivity which is a book about how to be more productive but in a way that's actually enjoyable meaningful and sustainable and it's that there is no achievement that you can possibly achieve that will make you any happier than you are right now that's not to say don't go for goals and achievements because it gives a sense of progress and momentum and it's you know something to pass the time but it is to say that we want to focus on enjoying the journey along the way there's this thing in Psychology called the arrival fallacy which is the idea that we believe that oh when I get to Point X or Y or Zed then I'll be happy but actually there is no happiness to be found in those points the happiness at those points is fairly fleeting doesn't last very long and so focus on enjoying the journey while at the same time pursuing your goals"

# %%
len(str(summarized_text2))
# Out:
# 297

# %%
str(summarized_text2)
# Out:
# 'There is no achievement that you can possibly achieve that will make you any happier than you are right now. Focus on enjoying the journey while at the same time pursuing your goals.  als. als als in the United States. In the U.S. they are called Americans. In Europe, they are known as Americans.'

# %% [markdown]
# ### **T5-Base Model**

# %%
# defining the model from Hugging Face Transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %%
# Encoding & decoding in T5. T5 uses a max_length of 512 so we cut the article to 512 tokens.

num_iters = int(len(result)/512)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  inp = tokenizer("summarize: " + result[start:end], return_tensors="pt", max_length=512, truncation=True)
  out = model.generate(inp["input_ids"], max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
  output = tokenizer.decode(out[0])
  summarized_text.append(output)

# %%
len(result)
# Out:
# 23817

# %%
result
# Out:
# " being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way if we want to make progress on our studies or in our work or in our side hustle or even like being present with our families for goodness sake that all requires this magical ability called focus it requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing the thing is we are bombarded by distractions all the time we have our social media notifications pinging right left and Center we have messages and emails and whatsapps and text messages and it's like it's so easy to get distracted these days with all of the Endless Options that we have available to us and the reason why I think it's so incredibly important to cultivate the ability to focus and this is the thing that I've really realized over the years that the quality of my life is directly proportional to my ability to focus and I've had periods of my life where I've really really really struggled to focus my first year of med school for example was a year where I really struggled to focus I was burning the midnight oil feeling really overwhelmed feeling really really stressed and didn't even do that well in my exams but then as I started to research more about productivity you know reading papers about it doing an extra degree in Psychology as well I I sort of realized that there there actually are a bunch of different techniques that we can learn to help us focus better and if we can just learn and apply those techniques it massively boosts the quality of our life okay so in this video we're going to go over the five key mistakes that cause us to get distracted and to not be able to focus and let's start with mistake number one now there was one thing that I read that really made this mistake hit home for me and that was when I read near eel's book indestructible this is a book about how to be indestructible and how to avoid distractions and all that kind of fun stuff and we're probably going to do a video about it at some point but right at the start of the book he says something like really really profound which is that the opposite of distraction is traction and traction is when you are doing something intentionally to move you towards where you want to go and distraction is when you are doing something that takes you away from where you want to go but then the next thing he says is that in order to actually know what the thing is you want to do and what the thing is you want to avoid you have to actually have a plan cuz if you don't have a plan you can't be distracted because you never had a plan to begin with distraction happens when we are intending to do one thing and then we find ourselves doing something else and so mistake number one that we all make that I make all the time when I find myself getting distracted is just not having a plan when you don't have a plan and you sit down at your computer or on your phone with nothing in mind as to what you actually want to do that is when you're going to end up doing all the other small things this is kind of what social media platforms are designed for when you go on a social media platform you don't usually go on it with a particular goal in mind it's like someone who's just browsing I'm just going to go on YouTube and I'm going to see what's up I'm literally Outsourcing the decision of how I'm going to spend my time which is the single most valuable resource that I have I'm Outsourcing that decision to a team of thousands of developers whose in whose goal is to keep me on the platform for as long as possible and to serve me ads for as long as possible so that the platform can make money I like the team behind YouTube I've met some of them they're very nice people but like those are the incentives of these social media platforms so the key thing is that we need to make a plan in order to avoid getting distracted and the single  ...

# %%
len(summarized_text)
# Out:
# 20

# %%
summarized_text
# Out:
# ["Being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way. It requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing. It's so easy to get distracted these days with all of the Endless Options.",
#  "There are a bunch of different techniques that we can learn to help us focus better. If we can just learn and apply those techniques it massively boosts the quality of our life. We're going to go over the five key mistakes that cause us to get distracted.",
#  " distraction is when we are intending to do one thing and then we find ourselves doing something else. In order to actually know what the thing is you want to do you have to actually have a plan cuz if you don't have aPlan you can't be distracted.",
#  '"I\'m Outsourcing the decision of how I\'m going to spend my time which is the single most valuable resource that I have" "I like the team behind YouTube I\'ve met some of them they\'re very nice people" "The key thing is that we need to make a plan in order to avoid getting distracted"',
#  "The biggest mistake that people make that causes them to get distracted is not having a plan. If you don't use a calendar you should start using a calendar because it's gamechanging. When we set an intention when we set a goal for something way more likely to happen.",
#  "Once you've mastered the ability to focus and not get distracted then one of the things you're going to have to figure out is what you actually want to do with all of that spare time that you've got freed up. If you are in the content creation World in any capacity then one thing that can really help you with ideas or titles or thumbnails or video scripts is generative AI which is becoming more and more important.",
#  'The guide will get you started with using AI in terms of the different AI tools and how to write prompts for them and all the different ways to use AI for your content business. It will help you understand how to simplify your research how to repurpose content and break through writer block as well.',
#  "People often blame themselves for being distracted, but it's because of negative emotions. People often ignore how they feel and don't understand what they're trying to avoid. People also blame social media companies.",
#  "There are broadly three categories of negative emotion that we try and avoid boredom anxiety and self-doubt again not sexy stuff to say if you're a dude watching this but like I I feel anxious and I feel self-Doubt. I feel low confidence about my ability to do this task.",
#  '"I had so much anxiety and so much self-doubt around my ability to write a book like oh what if people don\'t like it what if the reviews are bad what if it\'s like why would anyone care what I have to say all of these feelings around fear really block me"',
#  "FBR: I have pretty high confidence in my ability to make something fast and bad and wrong. I've also got a bunch of strategies in chapter 5 of my book around how we can overcome the negative emotion of fear. The task that we're trying to do is just really really really boring unfortunately we all have to do things that are not that are kind of boring.",
#  "These are the three PS that we can apply to whatever work we're doing to make it more fun. these days normally I have it as a Post-It note on my computer monitor. If the thing is a little bit more enjoyable then you are a lot less likely to get distracted.",
#  "A psychological concept called attention residue. When you switch from task a to task B your attention doesn't instantly follow. There is a residue of your focus that stays stuck on task a. This residue can completely ruin your performance on the current task.",
#  "The key lesson here is when you are doing something do one thing at a time. lock might make you feel like you're doing a lot of work but it can actually be counterproductive.",
#  '"I had about 18 unright messages on slack that I got I was tagged in and I was thinking you know what that\'s fine I\'m not even going to look at them" "I just know that if I even look at those 1800 messages it\'s going to cause some sort of attention residue" "The more intentional we can be with the blocks of time that we have in our calendar"',
#  'When I was doing the research for my book there was a tech company that I discovered called the drum group. They found that the most productive employees worked Less hours and took more breaks than the least productive employees. They founded the group Elite workers I.E the to ly matter to us.',
#  '"I really like having these two numbers in mind 52 and 17 they\'re kind of weird numbers like you know I wish there was there probably a better way of like I don\'t know 50 and 15 or something but 5217 is like a pretty reasonable ratio of work to break time" "I certainly find for myself whenever I\'m working on something I have like a Lord of the Rings music in the background"',
#  "There's a couple of different ways that we can apply this Insight one way of doing it is by setting yourself an intention that for the next 45 minutes or 50 minutes or 30 minutes or hour like you time block a certain amount of time where you intend to be focused on that one task and you don't deviate from that task during that time. For me personally I prefer to whack on the Lord of the Ring soundtrack and then I just work for as long as it takes me.",
#  "When I find myself getting distracted or like wanting to do something else I'll look at the timer and I'll see okay cool 38 minutes of past that's fine it's time to take a break. The thing that you do during the break should not generate any additional obligations.",
#  'One of the biggest things that ruins our focus and causes us to get distracted is problems with our Hardware I.E our body and our brain in terms of diet and exercise. I find that going to the gym four or five times a week in the mornings is incredibly helpful for my energy levels.']

# %% [markdown]
# ### **Distilbart Model**

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# iterating in batches
num_iters = int(len(result)/1000)

summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end], min_length = 30, max_length = 100)
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

#print(summarized_text)
# Out:
# input text
#  being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way if we want to make progress on our studies or in our work or in our side hustle or even like being present with our families for goodness sake that all requires this magical ability called focus it requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing the thing is we are bombarded by distractions all the time we have our social media notifications pinging right left and Center we have messages and emails and whatsapps and text messages and it's like it's so easy to get distracted these days with all of the Endless Options that we have available to us and the reason why I think it's so incredibly important to cultivate the ability to focus and this is the thing that I've really realized over the years that the quality of my life is directly proportional to my ability to focus and I've had period
# Summarized text
#  Being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way . The quality of my life is directly proportional to my ability to focus and I've had period period period. Being present with our families for goodness sake requires this magical ability called focus .
# input text
# s of my life where I've really really really struggled to focus my first year of med school for example was a year where I really struggled to focus I was burning the midnight oil feeling really overwhelmed feeling really really stressed and didn't even do that well in my exams but then as I started to research more about productivity you know reading papers about it doing an extra degree in Psychology as well I I sort of realized that there there actually are a bunch of different techniques that we can learn to help us focus better and if we can just learn and apply those techniques it massively boosts the quality of our life okay so in this video we're going to go over the five key mistakes that cause us to get distracted and to not be able to focus and let's start with mistake number one now there was one thing that I read that really made this mistake hit home for me and that was when I read near eel's book indestructible this is a book about how to be indestructible and how to avo
# Summarized text
#  In this video we're going to go over the five key mistakes that cause us to get distracted and to not be able to focus . In the video, we'll go over what we do to avoid getting distracted and how to be distracted .
# input text
# id distractions and all that kind of fun stuff and we're probably going to do a video about it at some point but right at the start of the book he says something like really really profound which is that the opposite of distraction is traction and traction is when you are doing something intentionally to move you towards where you want to go and distraction is when you are doing something that takes you away from where you want to go but then the next thing he says is that in order to actually know what the thing is you want to do and what the thing is you want to avoid you have to actually have a plan cuz if you don't have a plan you can't be distracted because you never had a plan to begin with distraction happens when we are intending to do one thing and then we find ourselves doing something else and so mistake number one that we all make that I make all the time when I find myself getting distracted is just not having a plan when you don't have a plan and you sit down at your comp
# Summarized text
#  The opposite of distraction is traction and traction is when you are doing something intentionally to move you towards where you want to go . If you don't have a plan you can't be distracted because you never had a plan to begin with distraction happens .
# input text
# uter or on your phone with nothing in mind as to what you actually want to do that is when you're going to end up doing all the other small things this is kind of what social media platforms are designed for when you go on a social media platform you don't usually go on it with a particular goal in mind it's like someone who's just browsing I'm just going to go on YouTube and I'm going to see what's up I'm literally Outsourcing the decision of how I'm going to spend my time which is the single most valuable resource that I have I'm Outsourcing that decision to a team of thousands of developers whose in whose goal is to keep me on the platform for as long as possible and to serve me ads for as long as possible so that the platform can make money I like the team behind YouTube I've met some of them they're very nice people but like those are the incentives of these social media platforms so the key thing is that we need to make a plan in order to avoid getting distracted and the single b
# Summarized text
#  Social media platforms are designed for when you go on a social media platform you don't usually go on it with a particular goal in mind it's like someone who's just browsing I'm just going to go on YouTube and I'm going to see what's up . The key thing is that we need to make a plan in order to avoid getting distracted .
# input text
# iggest mistake that people make that causes them to get distracted is not having a plan this is something n talks about in his book as well he says you know whenever people come to me and they say I'm struggling with distraction I struggle to get distracted he says show me your calendar and show me what you were what you were intending to do in that time block a if you don't use a calendar you should start using a calendar because it's gamechanging because it's Lally a log of what you intend to do and B if you have created a Time block let's say the in in this hourong time block I'm intending to write my PowerPoint presentation or I'm intending to work on my book or I'm intending to film a video or I'm intending to study for the exam whatever the thing is once it is in there as an intention now you can actually have traction and move towards it and the remarkable thing about the human brain is that when we set an intention when we set a goal for something way more likely to Marshall up
# Summarized text
#  The biggest mistake that people make that causes them to get distracted is not having a plan . Using a calendar is gamechanging because it's Lally a log of what you intend to do and B if you have created a Time block let's say the in in in this hourong time block I'm intending to write my PowerPoint presentation .
# input text
#  all the rare all the all the relevant resources and kind of mental faculties to get there whereas if we don't set a goal we just going to be ending up kind of a drift now once you've mastered the ability to focus and not get distracted then one of the things you're going to have to figure out is what you actually want to do with all of that spare time that you've got freed up and I know a lot of people in my audience are aspiring content creators or current content creators now if you are in the content creation World in any capacity then one thing that can really help you with ideas or titles or thumbnails or video scripts is generative AI which is becoming more and more important and if you want to learn more about using AI for your YouTube channel or your content creative business then I would really recommend you check out the completely free ebook that's written by hopspot which is called using generative AI to scale your content operations there is a link in the video descriptio
# Summarized text
#  Once you've mastered the ability to focus and not get distracted then one of the things you're going to have to figure out is what you actually want to do with all of that spare time that you've got freed up . If you are in the content creation World in any capacity then one thing that can really help you with ideas or titles or thumbnails or video scripts is generative AI which is becoming more and more important .
# input text
# n you can downloaded completely for free and it's an amazing guide that will get you started with using AI in terms of the different AI tools and how to write prompts for them and all the different ways to use AI for your content business you'll understand how to simplify your research how to repurpose content and how to break through writer block as well and me and my team have really found the example prompts and tips in particular for working with AI particularly useful because we are still trying to figure out how to leverage AI for our content but in a way that still retains my voice and like Good Vibes and authenticity and all that kind of fun stuff but does in fact use this amazingly powerful tool that we now have access to this ebook was made by HubSpot which is today's video sponsor so thank you very much to HubSpot for sponsoring the video and make sure you check out the completely free resource okay let's move on to mistake number two now once you've made a plan and you're s
# Summarized text
#  The video was made by HubSpot which is today's video sponsor for the video . It's an amazing guide that will get you started with using AI in terms of the different AI tools and how to write prompts for them .
# input text
# itting down to do the thing whatever the thing is and you still are finding yourself getting distracted by whatever then the mistake people make is thinking I'm just a distracted person or I just can't focus or you know you start telling yourself these identity type statements that's like a key mistake uh another mistake is to blame the social media companies sure we can blame the social media companies will we like but like you know fundamentally it's our job to control our and psychology and all that all that fun stuff but really generally when we once we've got a plan and we get distracted it's because we are it's it's because there's some sort of negative emotion that's at the root of our distraction and so really mistake number two is ignoring how you feel this is a lot easier for guys to do because normally dudes are really bad me included at understanding how they feel about stuff you might not even be aware that there is some sort of negative feeling that you're trying to avoid
# Summarized text
#  It's our job to control our and psychology and all that fun stuff but generally when we once we've got a plan and we get distracted it's because there's some sort of negative emotion that's at the root of our distraction and so really mistake number two is ignoring how you feel .
# input text
#  but here is a rule that I like to I like to think of in my life whenever I'm getting distracted provided I've got a plan I will just assume that there is some sort of emotion that I'm trying to avoid that's all there is to it step one do I have a plan and step two okay I have a plan and I'm getting distracted therefore what is the negative emotion I'm trying to avoid now there are broadly three categories of negative emotion that we try and avoid boredom anxiety and self-doubt again not sexy stuff to say if you're a dude watching this but like I I feel anxious and I feel self-doubt and I feel low confidence about my ability to do this task it's not a thing that we find it very easy to admit to ourselves but it's true let's start with the anxiety and the self-doubt because like generally the feeling the negative emotion behind these two things is fear I am afraid I'm not good enough I'm afraid to do this thing I got this a lot when I was writing my book I really struggled cuz I had my
# Summarized text
#  When I'm getting distracted provided I've got a plan I will assume that there is some sort of emotion that I'm trying to avoid that's all there is to it . There are broadly three categories of negative emotion that we try and avoid boredom anxiety and self-doubt .
# input text
# time block I had my plan to write however many hundred words or however many thousand words during the session but I had so much anxiety and so much self-doubt around my ability to write a book like oh what if people don't like it what if the reviews are bad what if it's like why would anyone care what I have to say all of these feelings around fear really block me and then I would feel the negative emotion come up sometimes I'd be aware of it other times I won't be aware of it and it would just be easier to soothe Myself by opening up my phone or going on YouTube and watching asmin gold TV doing a video iay about World of Warcraft or something like that I wasn't acknowledging the fact that really the reason I was getting distracted was because I was avoiding this feeling of fear this feeling of anxiety and then this feeling of self-doubt and you know the the hack I found for this was you know there's various hacks that Writers come up with to overcome this righteous block because writ
# Summarized text
#  Fear really block me and then I would feel the negative emotion come up sometimes I'd be aware of it other times I won't be aware . It would just be easier to soothe Myself by opening up my phone or going on YouTube and watching asmin gold TV .
# input text
# ers block is fundamentally like some sort of feeling that we're that we're struggling to deal with but one way I found to deal with that was just the idea of fast bad wrong FBR and it's like if the goal is to make something fast and bad and wrong then great yeah I I have pretty high confidence in my ability to make something fast bad and wrong and therefore the negative emotion goes away I've also got a bunch of strategies in chapter 5 of my book around like how we can overcome the negative emotion of fear but like that is a big part of why we get distracted because there is some sort of anxiety or self-doubt that we're feeling the second big part of why why we get distracted is because the task that we're trying to do is just really really really boring unfortunately we all have to do things at times that are not that are kind of boring the trick here is something that I have on my phone my phone wallpaper if this focuses What would this look like if it were fun I have it on my phone
# Summarized text
#  If the goal is to make something fast and bad and wrong then great yeah I I have pretty high confidence in my ability to make it fast bad and bad then great . I've also got a bunch of strategies in chapter 5 of my book around how we can overcome the negative emotion of fear . The trick here is something that I have on my phone my phone wallpaper .
# input text
# these days normally I have it as a Post-It note on my computer monitor what would this look like if it were fun how do you make your work feel good how do you make it enjoyable and how do you make it energizing in the book we talk about play and power and people these are the three PS that we can apply to whatever work we're doing to make it more fun because if the thing is a little bit more enjoyable then you are a lot less likely to get distracted by the thing oh and by the way if you're interested in learning more about what near says in the book indistractable you should read the book but if you don't want to read the book you can absolutely check out the summary of that book over on short form they're not sponsoring this video but I do have an affiliate link down below they even have a summary of my book so if for whatever reason you don't want to read this and you'd rather read a book summary of it you can check it out on short form uh there's a link down below it's an affiliate
# Summarized text
#  These are the three PS that we can apply to whatever work we're doing to make it more fun . these days normally I have it as a Post-It note on my computer monitor what would this look like if it were fun?
# input text
# link but it does also give you 20% discount if you feel like reading book summaries it's my favorite source of book summaries all right now we come to mistake number three and the way we understand this is a psychological concept called attention residue now this is a term that was introduced by Professor Sophie Leroy at the University of Washington in a paper published in 2009 now in her work Sophie shows that when you switch from task a to task B your attention doesn't instantly follow there is a residue of your focus that stays stuck on task a and this residue on the previous task can completely ruin your performance on the current task because your brain is not yet fully transitioned to the next task and really the thing is that our brains are not designed to keep parallel tracks of attention going it is a lot easier for us to focus on one thing at a time rather than try and sort of split our Focus across multiple things and so switching between many different tasks within a work b
# Summarized text
#  The way we understand this is a psychological concept called attention residue . This is a term that was introduced by Professor Sophie Leroy at the University of Washington in 2009 . Our brains are not designed to keep parallel tracks of attention going .
# input text
# lock might make you feel like you're doing a lot of work but it can actually be really counterproductive and cause you to get distracted and so the key lesson here is when you are doing something do one thing at a time trying to work on your writing and also reply to slack messages and also reply to this email and also work on this other design task that you're doing at the same time it's just not going to work like trying to do things in parallel generally is a lot less efficient and a lot less effective than trying to do things in series I.E just one at a time practical thing here is for example turn off notifications turn on the focus mode on your phone and on all your devices I have the feature on on my Apple devices that shares Focus mode between devices so I'm not even going to see notifications if they pop up I always have my phone face down on the table in front of me so that I don't even see the notifications and just before filming this video I opened up slack and I saw that
# Summarized text
#  Lock might make you feel like you're doing a lot of work but it can actually be counterproductive and cause you to get distracted . The key lesson here is when you are doing something do one thing at a time . Turn off notifications turn on the focus mode on your phone and on all your devices .
# input text
# I had about 18 unright messages on slack that I got I was tagged in and I was thinking you know what that's fine I'm not even going to look at them because I just know that if I even look at those 1800 messages it's going to cause some sort of attention residue it's going to cause me to lose focus it's going to get me distracted sometimes what I like to do is in the middle of day like like maybe after having lunch or something where I've got half an hour of like empty empty time before the next meeting or whatever I'll use that time to do the shallow work to just kind of go through WhatsApp and reply to things and just generally wander around somewhat aimlessly kind of replying to stuff here and there and that's fine but it's fine because that's sort of the intention that I've made for that particular block of time the more intentional we can be with the blocks of time that we have in our calendar and and in our life the more likely we are to actually make time for the things that real
# Summarized text
#  I had about 18 unright messages on slack that I got I was tagged in and I was thinking you know what that's fine I'm not even going to look at them because I just know that if I even look at those 1800 messages it's going to cause some sort of attention residue . Sometimes what I like to do is in the middle of day like like maybe after having lunch or something where I've got half an hour of like empty empty time before the next meeting or whatever
# input text
# ly matter to us oh by the way if you're enjoying this video so far then you might like to check out my completely free 7-Day Focus crash course it's at Focus crashcourse tocom it's completely free you enter your email and then every day for 7 days I'll send you an email that has some principles and strategies and evidence-based tips on how to become more focused so completely free check it out all right let's talk about mistake number four now so when I was doing the research for my book there was a tech company that I discovered called the drum group and basically this company wanted to find out what made their most productive employees different from their least productive employees basically what they found was that the most productive employees worked Less hours and took more breaks than the least productive employees and so what they did was they used a Time tracking app that they installed in all their people's devices and stuff and they founded the group Elite workers I.E the to
# Summarized text
#  When I was doing the research for my book there was a tech company that I discovered called the drum group and basically this company wanted to find out what made their most productive employees different from their least productive employees . What they found was that the most . productive employees worked Less hours and took more breaks than the least productive . employees .
# input text
# p 10% in terms of productivity they worked intensely for 52 minutes on average and then they would take the next 17 minutes off and within those 52 minutes they were doing intense focused deep work single tasking focusing on just one thing and then in the next 17 minutes these guys were really resting so they weren't really checking slack or like looking at email every 5 minutes they were actively taking a break during that time and I really like having these two numbers in mind 52 and 17 they're kind of weird numbers like you know I wish there was there probably a better way of like I don't know 50 and 15 or something but 5217 is like a pretty reasonable ratio of work to break time and I certainly find for myself whenever I'm working on something I have like a Lord of the Rings music in the background and I can see how much time has elapsed in the three-hour playlist and usually by the time it gets to 40 50 minutes I start to feel myself itching to do something else itching to get dis
# Summarized text
#  p 10% in terms of productivity they worked intensely for 52 minutes on average and then they would take the next 17 minutes off . Within those 52 minutes they were doing intense focused deep work single tasking focusing on just one thing . The next 17 17 minutes these guys were really resting so they weren't really checking slack or like looking at email every 5 minutes .
# input text
# tracted and like wanting to check emails and stuff and then I look at the timer and I'm like oh okay it's been 48 minutes now it's time to take a break okay so there's a couple of different ways that we can apply this Insight one way of doing it is by setting yourself an intention that for the next 45 minutes or 50 minutes or 30 minutes or hour like you time block a certain amount of time where you intend to be focused on that one task and you don't deviate from that task during that time for me personally I don't really like that style approach where I sort of fix fixedly like give myself a fixed amount of time to do the thing un unless I have like a meeting coming up or something that I have to do in which case obviously I'll give myself a fixed amount of time generally what I prefer to do is I prefer to whack on the Lord of the Ring soundtrack and then I just work for as long as it takes me to feel as if I can just make full full Focus progress on that one task whatever the thing I'
# Summarized text
#  There's a couple of different ways that we can apply this Insight one way of doing it is by setting yourself an intention that for the next 45 minutes or 50 minutes or 30 minutes or hour like you time block a certain amount of time where you intend to be focused on that one task and you don't deviate from that task .
# input text
# m doing is and then when I do find myself getting distracted or like wanting to do something else I'll look at the timer and I'll see okay cool 38 minutes of past that's fine it's time to take a break and I sort of recognize that feeling Within Myself that when I feel the need to do something else that is when it is a very good time to take a break to get up to make a coffee to do a Wii to do whatever the thing is and the key thing to remember is that the thing that you do during the break should not generate any additional obligations because if for example you use your brakes to check your messages now checking messages is going to generate a bunch of random tasks for you to do and then that's going to cause you to get distracted from the thing that you are actually trying to do next so take a break take a proper break do something that does not generate any additional obligations and tasks on your time ideally and now we come to mistake number five and and for most of this video act
# Summarized text
#  When I find myself getting distracted or like wanting to do something else I'll look at the timer and I'll see okay cool 38 minutes of past that's fine it's time to take a break . The key thing to remember is that the thing that you do during the break should not generate any additional obligations .
# input text
# ually for all this video we've been talking about software problems problems with you know the way that we respond to things in our brain or the way that we operate this is problems with the software but one of the biggest things that ruins our focus and causes us to get distracted is problems with our Hardware I.E our body and our brain in terms of diet and exercise and in particular sleep this is the stuff everyone already knows you should be sleeping 8 hours a night you should be eating healthy food we all know what healthy food is eat like an adult don't eat like a child we should be doing exercise every day ideally I found it incredibly helpful just going to the gym first thing in the morning so for example this morning from 8:00 till 9:00 a.m. I had a gym session and yesterday was leg day and the day before that which was was chess day and I find that going to the gym four or five times a week in the mornings is incredibly helpful for my energy levels and for my ability to not ge
# Summarized text
#  One of the biggest things that ruins our focus and causes us to get distracted is problems with our Hardware I.E our body and our brain in terms of diet and exercise and in particular sleep . You should be sleeping 8 hours a night you should be eating healthy food and exercise every day .
# input text
# t distracted during the day unfortunately I didn't get much sleep last night because I was watching Dune po 2 and then I got home at like midnight and then my mind was buzzing because I watched a few video essays about like how Dune part 2 was made and then I was buzzing with all the things and I was like oh okay damn you know my brain's on got I've got to wake up for the gym at 7:30 damn sleep time is cut down and I was like okay cool I need to meditate and so I didn't get my 8 hours of sleep unfortunately which is why today I know I'm more likely to have issues as as it relates to focus and getting distracted which means I need to be even more on my aame and just really focus on building that plan not falling into these other software mistakes to make up for the fact that I've had only like 4 and a half hours of sleep last night because I was watching videos about June part two it becomes a lot easier to stay focused and not get distracted when you have taken care of the hardware stu
# Summarized text
#  I didn't get much sleep last night because I was watching Dune po 2 and then I got home at like midnight and then my mind was buzzing because I watched a few video essays about how Dune part 2 was made . I need to be even more on my aame and just really focus on building that plan not falling into these other software mistakes .
# input text
# ff so if you're not sleeping if you're eating like crap and if you're not getting exercise of course you're going to struggle to focus like you can't expect to be able to focus if this hardware and if your health is absolutely terrible so often when it comes to software problems you kind of want to deal with the hardware stuff first one thing that my friend s Bloom often says is that you know there is no such thing as a loser who wakes up at 5:00 a.m. and does a workout you know when I first heard him say that I was like huh are you saying everyone has to wake up at 5:00 a.m. it's like that's not what he's saying what he's saying is that if you wake up an hour earlier and just exercise you are going to be taking care of yourself in a way that you might not be doing otherwise and that actually bleeds into all of the other areas of your life and really helps you to stay focused and avoid distraction this is why every single highflying CEO I've ever spoken to works out first thing in the
# Summarized text
#  There is no such thing as a loser who wakes up at 5:00 a.m. and does a workout, says Bloom . Bloom: "If you wake up an hour earlier and just exercise you are going to be taking care of yourself in a way that you might not be doing otherwise"
# input text
# morning but generally when I speak to people when at events and talks that I do if someone comes up to me and says that they struggle with distraction or they struggle with staying focused and I have time to talk to them about a few things usually I find out that they're not exercising they're not eating particularly well and they're not sleeping particularly well so in that case of course you're going to struggle with focus and of course you're going to get distracted so I would say the thing to keep in mind and the thing that I like to keep on reminding myself is that yes we can have all these software issues yes we can install all the apps in the world and use the focus modes and all that kind of stuff but without the hardware without our body and our mind being in tiptop shape it's going to be really hard to do all this stuff but if our body and mind is in tiptop shape it becomes a lot easier to do all of these things that we want to do okay so hopefully you got something from this
# Summarized text
#  When I speak to people when at events and talks that I do if someone comes up to me and says that they struggle with distraction, I would say the thing to keep in mind is that yes we can have all these software issues . Without the hardware without our body and our mind being in tiptop shape it's going to be really hard .
# input text
#  video I would love for you to leave a comment down below about one actionable thing that you're going to do to apply in your life in order to not get distracted and to focus better and if you're interested in hearing more this video is actually the first in a three-part series that we're working on about how to be more focused because we realize that when we poll our audience and stuff that like everyone really struggles with focus and so we're going to make more videos about it and video number two is going to be about some strategies and techniques that you can use and video number three is going to be about my favorite tools to stay more focused so those videos will be right over there in this little playlist that I've created for you thank you so much for watching and see you in the next video bye-bye
# Summarized text
#  This video is the first in a three-part series that we're working on about how to be more focused . I would love for you to leave a comment down below about one actionable thing that you're going to do to apply in your life in order to not get distracted and to focus better .

# %%
len(result)
# Out:
# 23817

# %%
result
# Out:
# " being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way if we want to make progress on our studies or in our work or in our side hustle or even like being present with our families for goodness sake that all requires this magical ability called focus it requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing the thing is we are bombarded by distractions all the time we have our social media notifications pinging right left and Center we have messages and emails and whatsapps and text messages and it's like it's so easy to get distracted these days with all of the Endless Options that we have available to us and the reason why I think it's so incredibly important to cultivate the ability to focus and this is the thing that I've really realized over the years that the quality of my life is directly proportional to my ability to focus and I've had periods of my life where I've really really really struggled to focus my first year of med school for example was a year where I really struggled to focus I was burning the midnight oil feeling really overwhelmed feeling really really stressed and didn't even do that well in my exams but then as I started to research more about productivity you know reading papers about it doing an extra degree in Psychology as well I I sort of realized that there there actually are a bunch of different techniques that we can learn to help us focus better and if we can just learn and apply those techniques it massively boosts the quality of our life okay so in this video we're going to go over the five key mistakes that cause us to get distracted and to not be able to focus and let's start with mistake number one now there was one thing that I read that really made this mistake hit home for me and that was when I read near eel's book indestructible this is a book about how to be indestructible and how to avoid distractions and all that kind of fun stuff and we're probably going to do a video about it at some point but right at the start of the book he says something like really really profound which is that the opposite of distraction is traction and traction is when you are doing something intentionally to move you towards where you want to go and distraction is when you are doing something that takes you away from where you want to go but then the next thing he says is that in order to actually know what the thing is you want to do and what the thing is you want to avoid you have to actually have a plan cuz if you don't have a plan you can't be distracted because you never had a plan to begin with distraction happens when we are intending to do one thing and then we find ourselves doing something else and so mistake number one that we all make that I make all the time when I find myself getting distracted is just not having a plan when you don't have a plan and you sit down at your computer or on your phone with nothing in mind as to what you actually want to do that is when you're going to end up doing all the other small things this is kind of what social media platforms are designed for when you go on a social media platform you don't usually go on it with a particular goal in mind it's like someone who's just browsing I'm just going to go on YouTube and I'm going to see what's up I'm literally Outsourcing the decision of how I'm going to spend my time which is the single most valuable resource that I have I'm Outsourcing that decision to a team of thousands of developers whose in whose goal is to keep me on the platform for as long as possible and to serve me ads for as long as possible so that the platform can make money I like the team behind YouTube I've met some of them they're very nice people but like those are the incentives of these social media platforms so the key thing is that we need to make a plan in order to avoid getting distracted and the single  ...

# %%
len(str(summarized_text))
# Out:
# 5986

# %%
str(summarized_text)
# Out:
# '["Being able to not get distracted is genuinely one of the most life-changing skills if we want to improve our lives in any way. It requires the ability to focus on one thing and one thing only and to be fully present in just doing that one bloody thing. It\'s so easy to get distracted these days with all of the Endless Options.", "There are a bunch of different techniques that we can learn to help us focus better. If we can just learn and apply those techniques it massively boosts the quality of our life. We\'re going to go over the five key mistakes that cause us to get distracted.", " distraction is when we are intending to do one thing and then we find ourselves doing something else. In order to actually know what the thing is you want to do you have to actually have a plan cuz if you don\'t have aPlan you can\'t be distracted.", \'"I\\\'m Outsourcing the decision of how I\\\'m going to spend my time which is the single most valuable resource that I have" "I like the team behind YouTube I\\\'ve met some of them they\\\'re very nice people" "The key thing is that we need to make a plan in order to avoid getting distracted"\', "The biggest mistake that people make that causes them to get distracted is not having a plan. If you don\'t use a calendar you should start using a calendar because it\'s gamechanging. When we set an intention when we set a goal for something way more likely to happen.", "Once you\'ve mastered the ability to focus and not get distracted then one of the things you\'re going to have to figure out is what you actually want to do with all of that spare time that you\'ve got freed up. If you are in the content creation World in any capacity then one thing that can really help you with ideas or titles or thumbnails or video scripts is generative AI which is becoming more and more important.", \'The guide will get you started with using AI in terms of the different AI tools and how to write prompts for them and all the different ways to use AI for your content business. It will help you understand how to simplify your research how to repurpose content and break through writer block as well.\', "People often blame themselves for being distracted, but it\'s because of negative emotions. People often ignore how they feel and don\'t understand what they\'re trying to avoid. People also blame social media companies.", "There are broadly three categories of negative emotion that we try and avoid boredom anxiety and self-doubt again not sexy stuff to say if you\'re a dude watching this but like I I feel anxious and I feel self-Doubt. I feel low confidence about my ability to do this task.", \'"I had so much anxiety and so much self-doubt around my ability to write a book like oh what if people don\\\'t like it what if the reviews are bad what if it\\\'s like why would anyone care what I have to say all of these feelings around fear really block me"\', "FBR: I have pretty high confidence in my ability to make something fast and bad and wrong. I\'ve also got a bunch of strategies in chapter 5 of my book around how we can overcome the negative emotion of fear. The task that we\'re trying to do is just really really really boring unfortunately we all have to do things that are not that are kind of boring.", "These are the three PS that we can apply to whatever work we\'re doing to make it more fun. these days normally I have it as a Post-It note on my computer monitor. If the thing is a little bit more enjoyable then you are a lot less likely to get distracted.", "A psychological concept called attention residue. When you switch from task a to task B your attention doesn\'t instantly follow. There is a residue of your focus that stays stuck on task a. This residue can completely ruin your performance on the current task.", "The key lesson here is when you are doing something do one thing at a time. lock might make you feel like you\'re doing a lot of work but it can actually be counterproductive.", \'"I had about 18 u ...

# %% [markdown]
# ### **Text to speech**

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.19.1 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
import torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# ERROR: Operation cancelled by user

# %%
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import torch
import soundfile as sf
from datasets import load_dataset

processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

inputs = processor(text="Hello, how are you", return_tensors="pt")

# load xvector containing speaker's voice characteristics from a dataset
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

sf.write("speech.wav", speech.numpy(), samplerate=16000)
